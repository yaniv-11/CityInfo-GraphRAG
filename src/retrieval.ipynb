# %% [markdown]
# # Task
# Integrate previously generated text embeddings stored in Chroma DB with triplets built from extracted data for building a graph RAG system and demonstrate how to query this integrated system.

# %% [markdown]
# ## Understand the triplet structure
#
# ### Subtask:
# Review the format and content of the triplets you have generated to understand the entities and relationships in your knowledge graph.

# %% [markdown]
# **Reasoning**:
# Load the JSON file containing the triplets into a pandas DataFrame and display the first few rows to understand its structure and content.

# %%
import pandas as pd
import json

with open('/content/triplets.json', 'r') as f:
    triplets_data = json.load(f)

df_triplets = pd.DataFrame(triplets_data)
display(df_triplets.head())
# Out:
#                               subject                   relation  \
# 0  Bruhat Bengaluru Mahanagara Palike                  published
# 1                 Senior IAS officers               appointed as
# 2      Financial and Technical powers               delegated to
# 3                    Zonal Committees                 formed for
# 4                           225 wards  formed in accordance with
#
#                                        object
# 0               Performance Report of 2024-25
# 1                         Zonal Commissioners
# 2     Zonal Commissioners and other officials
# 3  administration and management of 225 wards
# 4                             BBMP Act - 2020

# %% [markdown]
# **Reasoning**:
# Analyze the types of entities and relationships present in the triplets to get an overview of the knowledge graph's content by inspecting the unique values in the 'relation' column.

# %%
print("Unique relations in the triplets:")
print(df_triplets['relation'].unique())

print("\nNumber of unique subjects:")
print(df_triplets['subject'].nunique())

print("\nNumber of unique objects:")
print(df_triplets['object'].nunique())
# Out:
# Unique relations in the triplets:
# ['published' 'appointed as' 'delegated to' 'formed for'
#  'formed in accordance with' 'appointed for' 'is present in' 'resolves'
#  'prepared for' 'will be submitted to' 'commenced' 'is for' 'is through'
#  'approved by' 'came into effect from' 'transferred through'
#  'submitted by' 'is' 'is taking action to review and implement'
#  'is intended to be established by name' 'will maintain' 'facilitates'
#  'submitted to' 'received approval from' 'has been operationalized by'
#  'is equipped with' 'adopted by' 'are live for' 'provides' 'is secured by'
#  'is sanitized by' 'achieved' 'was' 'yielded' 'recovered'
#  'occurred between' 'led to' 'were promulgated by' 'are expected to yield'
#  'provide for' 'has been amended' 'are promulgated' 'has streamlined'
#  'was expected to be' 'have been received by' 'is expected to be'
#  'is expected to be released by' 'is issued by' 'will be implemented'
#  'will be approved with' 'requires' 'will be utilized for' 'allows'
#  'implemented' 'has been developed by' 'is incorporated into'
#  'is completed' 'is available on' 'can view' 'can check and correct'
#  'is enabled to secure' 'has been opened for' 'is developed for'
#  'is managed by' 'is implemented in' 'monitors and manages' 'is used for'
#  'will be used for' 'is ready for promulgation in' 'was launched in'
#  'operates in' 'has been' 'processed' 'fixed' 'rejected'
#  'are in progress to be fixed by' 'have been upgraded as per' 'belongs to'
#  'was implemented to identify' 'used' 'is near' 'utilizes'
#  'are installed under' 'shall be installed on' 'will be integrated with'
#  'is being integrated with' 'are being integrated under'
#  'has mandated that' 'is provided' 'is integrated with'
#  'is not integrated with' 'are studying under' 'operates'
#  'is functional in' 'are functional in' 'became functional from'
#  'facilitate' 'ensure' 'improve' 'received training through'
#  'was in collaboration with' 'were provided with' 'cost'
#  'were provided to' 'have been hired to improve' 'is in partnership with'
#  'has been implementing' 'started in' 'aims to enhance' 'supports'
#  'employs' 'aims to catalyze' 'is achieved by strengthening'
#  'aims to build' 'is built through' 'has been implemented in' 'reached'
#  'is across' 'was given prime importance in' 'are from' 'participated in'
#  'received' 'was conducted by' 'had' 'is procuring' 'is for keeping'
#  'are being provided with' 'have been procured and distributed to'
#  'has been taken up at the cost of' 'targets' 'collaborated with'
#  'aimed to provide' 'took BBMP school and college students on'
#  'were organized on' 'were organized to give an opportunity to'
#  'was awarded to' 'were awarded' 'passed in' 'is being put on'
#  'have been deployed for' 'are being regularly guided on' 'ensures'
#  'has started' 'are for' 'have been neutered as part of'
#  'have been vaccinated with' 'became the first corporation to launch'
#  'will be administered' 'has been initiated in' 'are'
#  'has been started to ensure' 'has been started to avoid'
#  'became the first corporation to start'
#  'are being fed in coordination with' 'has been started in'
#  'have been conducted at' 'were conducted through' 'identified'
#  'has been reimbursed for' 'have hosted' 'have been trained for'
#  'are involved in' 'have been supported with an aid of'
#  'intended to build' 'aims to promote' 'aims to showcase' 'aims for'
#  'aims to increase' 'was provided for' 'was provided in'
#  'has been proposed as' 'is issued for' 'have been'
#  'are being developed with' 'is implemented with the objective of'
#  'is implemented to ensure' 'will be developed to meet' 'will include'
#  'will be installed to accommodate' 'will ensure'
#  'is currently maintaining' 'is allocated in'
#  'took a landmark decision to keep' 'aims to make'
#  'are under progress for' 'were allocated under' 'were allocated for'
#  'have been constructed in' 'aims to improve' 'are being spent to'
#  'are under progress in' 'is a' 'is also known as'
#  'developed Hasiru Mitra in coordination with' 'aims to monitor'
#  'maintain' 'appoints agencies through' 'can visit' 'can enroll as'
#  'helps in' 'enables stakeholders to contribute'
#  'enables stakeholders to assist' 'assist BBMP in providing'
#  'are given for adoption under' 'identified need for' 'is based on'
#  'is part of' 'includes' 'has divided' 'form' 'will take place in'
#  'has been approved by' 'has been submitted to' 'will be spent on'
#  'has been accumulated under jurisdiction of' 'has been processed through'
#  'are in' 'will be processed through' 'is in' 'are under'
#  'are planned to be established in' 'have a capacity of'
#  'are operational in' 'will be' 'are under approval stage for'
#  'are planned to be established under' 'have been issued for'
#  'has a capacity of' 'is ongoing in' 'expected completion by'
#  'is planned in' 'will be constructed in' 'have been established in'
#  'increased' 'has been commissioned in' 'generates' 'is generated from'
#  'are being' 'are being constructed under' 'is at' 'are at'
#  'are being planned under' 'are also known as' 'is being composted at'
#  'is done by' 'takes place in' 'is being used for' 'has a'
#  'are employed in' 'are employed under' 'are working with' 'contribute to'
#  'approved' 'is under' 'invited for' 'will lead to up-gradation of'
#  'will have bed strength increased to' 'will boost' 'will provide'
#  'associated with' 'provided physiotherapy to' 'launched in' 'will track'
#  'aims to avoid' 'aims to ensure' 'procured to reduce'
#  'procured to improve' 'increased to' 'started at' 'benefit' 'enhances'
#  'planted in' 'planted during' 'received support from' 'done in'
#  'geo-tagged on' 'manages trees through' 'address' 'processed through'
#  'deployed during' 'deployed to cater to' 'being established under'
#  'costs' 'will raise' 'carried out using' 'carried out as per'
#  'counted in' 'classified' 'available for public view on'
#  'being developed under' 'are based on' 'being built near'
#  'has in its jurisdiction' 'is to develop' 'is to rejuvenate'
#  'is to maintain' 'aid in' 'have' 'enhance' 'include' 'in progress in'
#  'being spent for' 'under use for' 'can be used by'
#  'use Kere Mitra App to monitor' 'use Kere Mitra App to supervise'
#  'may enroll as' 'volunteer to submit' 'volunteer to raise reports to'
#  'available for' 'enables' 'can be raised by' 'can be raised on'
#  'deployed to provide' 'protects' 'coordinates with' 'aims to identify'
#  'aims to demarcate' 'aims to remove' 'demarcated with' 'secured with'
#  'declared' 'cleared in' 'cleared during' 'given for' 'given under'
#  'allocated under' 'allocated in' 'regulate' 'allow for' 'prevent'
#  'placed on' 'handed over to' 'aims to recharge' 'are interested in'
#  'is associated with' 'commenced operations in'
#  'marks a pivotal moment in'
#  'has primary objective to facilitate implementation of'
#  'has primary objective to spearhead implementation of'
#  'is implemented within jurisdictional limits of' 'is designed as'
#  'are integrated into' 'was characterized by'
#  'aimed to identify actions for' 'aimed to prioritize actions for'
#  'has taken a big step towards' 'integrates' 'tracks'
#  'provides framework for' 'assesses'
#  'are strategically allocated to achieve' 'foster'
#  'was a major milestone achieved by' 'serves as' 'provides access to'
#  'developed' 'provides information and answers queries related to'
#  'introduced a fellowship program in' 'aims to bolster implementation of'
#  'successfully onboarded' 'are actively contributing to' 'established'
#  'comprises' 'serves as a conduit for'
#  'were conducted to update members on' 'were conducted to enhance'
#  'created' 'launched' 'would enable BBMP to protect'
#  'would enable BBMP to review' 'are being verified by'
#  'was organized to involve' 'accelerated' 'helped identify'
#  'is launched for' 'enables citizens to participate in'
#  'was conducted, bringing together' 'included'
#  'aimed to correlate satellite surface temperature data from hottest months with'
#  'was conducted across' 'conducted' 'covered topics including'
#  'have been instituted to recognize' 'was conducted for' 'demonstrated'
#  'establishment of' 'active engagement with' 'implementation of'
#  'are instrumental in ensuring' 'are instrumental in fostering'
#  'has implemented' 'is for pourakarmikas who served for'
#  'have benefited from' 'has provided'
#  'have been established to facilitate' 'has deployed' 'are used to clean'
#  'was proposed by' 'is ready for' 'will come into effect from'
#  'will be awarded through' 'was developed in-house by'
#  'incorporates provision to impose' 'is to the extent of'
#  'incorporates provision to lodge' 'is expected to result in'
#  'publicizes the importance of' 'publicizes to' 'uses' 'publicizes'
#  'have been allotted to' 'is in progress for' 'have been uploaded to'
#  'came into force from' 'enable' 'will be fixed based on'
#  'will be acted upon under' 'is expected to generate' 'has begun under'
#  'has been approved for' 'was approved vide'
#  'has started functioning under' 'has approved' 'have an approved cost of'
#  'have been invited for' 'has been prepared for' 'will be executed after'
#  'is expected to be spent on "Sancharyukta Bengaluru" works during'
#  'have been provided for' 'have been prepared for'
#  'are being prepared for'
#  'is expected to be spent on RMP road widening in'
#  'is expected to be utilized in' 'have been allocated for'
#  'is expected to be utilized' 'will be deposited to'
#  'are expected to be spent in' 'is being carried out by'
#  'exists for depositing' 'is expected to be spent in' 'were provided for'
#  'has been realigned to' 'has approved action plan for' 'has a cost of'
#  'is earmarked for' 'will be spent from'
#  'has been provided in FY 2024-25 for' 'has been re-appropriated to'
#  'will be spent during' 'is under the head' 'is for FY'
#  'is expected to be spent in FY 2024-25 for'
#  'has been allocated in FY 2024-25 for' 'is for the project'
#  'was kept for' 'is submitted for' 'have been prepared by'
#  'will be created during' 'will be headed by' 'will look after'
#  'will advise on' 'is titled' 'was known as' 'is synonymous with' 'made'
#  'registered highest growth rate of' 'occurred in' 'has come under'
#  'is under the leadership of' 'invited [Foreword author] to chair'
#  'members include' 'met over' 'occurred over' 'represent' 'studied'
#  'considered' 'are set out in website' 'understood' 'sought services of'
#  'put in place' 'compiled' 'submitted' 'received valuable inputs for'
#  'has' 'is an eminently qualified member of' 'served as' 'contributed to'
#  'delineated' 'brought insights on' 'worked closely on' 'brought'
#  'facilitated' 'worked like' 'received inputs from' 'completed'
#  'completed translation in' 'establishes a need for' 'used a'
#  'has a present population of' 'is projected to have a population of'
#  'indicate a move towards' 'concluded that' 'will address' 'suggests'
#  'functions as' 'is responsible for' 'proposed' 'was a pioneer in'
#  'believes in' 'recommended' 'is an example of' 'expresses gratitude to'
#  'submitted its report on' 'was submitted to' 'provided'
#  'was constituted to' 'views Bengaluru as' 'involved' 'did not yield'
#  'lack' 'discussed with' 'operate in' 'lacked' 'agreed that'
#  'was upgraded' 'focused on' 'met with' 'was set up as' 'reviewed' 'heard'
#  'set up teams for' 'held' 'is the culmination of'
#  'was done with the support of' 'is plagued by'
#  'operate outside the control of' 'holds' 'do not have' 'mandates'
#  'is routinely' 'exists' 'effectively negates' 'are described as'
#  'exist for' 'suffer from' 'are considered' 'led citizens to'
#  'seems responsible for' 'leads to' 'is a manifestation of' 'govern'
#  'are detrimental to' 'needs' 'are a' 'lacks' 'are shrouded in'
#  'was implemented in' 'was not part of' 'has not occurred for'
#  'suffers from' 'has own revenue sources of'
#  'had pending bills as of Apr 1, 2015 of' 'had a loan of'
#  'had Spill over works of' 'is indicative of' 'paid' 'indicates'
#  'have not been revised since' 'is expected to determine' 'produces'
#  'are obsolete compared to' 'is a serious impediment to' 'is coupled with'
#  'manifests itself in' 'is in terms of' 'are often' 'is a major'
#  'is due to' 'is a glaring example of' 'results in' 'lead to'
#  'has been festering for' 'is without' 'focussed on' 'are holding back'
#  'is prevented from realising its potential as' 'needs to be'
#  'will call for' 'analyses' 'sets out' 'recommends' 'is guided by'
#  'focus on' 'strengthen' 'aim to give' 'is to address'
#  'are empowered to take' 'promotes' 'means' 'are devolved to' 'aim to'
#  'allows citizens to make their case for' 'is housed in'
#  'is housed within' 'change character to' 'suggested' 'has a footprint of'
#  'were formed during' 'were based on' 'grew by 44.6% during'
#  'is the highest in' 'has a population of' 'grew by about 18% during'
#  'had a 2011 population of' 'have a population of'
#  'has a current population of' 'need' 'are growing' 'is growing'
#  'could be fixed at' 'is a necessary prerequisite for' 'revealed'
#  'exists between' 'is manifest in' 'are not' 'are not held in' 'ignore'
#  'are rooted in' 'will have' 'is achieved through' 'is chaired by'
#  'number' 'would indicate' 'can be filled by' 'will be representative of'
#  'will be managed by' 'currently have' 'will be entrusted with'
#  'aim to ensure' 'are an input for' 'are expected to address'
#  'will communicate' 'are currently allocated' 'is an area where'
#  'should be incentivised to enhance' 'should set out' 'would need'
#  'should devolve to' 'is for financing' 'is at the discretion of' 'expect'
#  'cannot reasonably reorganise' 'is proposed to have'
#  'is well versed with' 'are proposed to be capable of resolving'
#  'is proposed to serve' 'is proposed to be achieved through'
#  'is a type of' 'is not' 'is projected to be over'
#  'finds it near impossible to' 'is necessary for' 'involves transfer from'
#  'involves transfer to' 'are handed over from' 'have discussed'
#  'currently has' 'experienced' 'was to'
#  'has not been achieved as an objective of' 'have suffered in terms of'
#  'lives in' 'have less than' 'have complained of' 'has an area of'
#  'operates as' 'follow' 'is considered useful as' 'is necessary between'
#  'is strong across' 'is projected to continue until' 'has occurred beyond'
#  'is projected to sustain over' 'was approximately equal to'
#  'is projected to increase relative to' 'are identified as'
#  'tried combinations of' 'was considered' 'did not scale well over'
#  'was considered too large to' 'was identified as' 'balanced'
#  'kept intact' 'has scope to scale'
#  'could be resolved more effectively by' 'would focus on' 'would oversee'
#  'would be more effective than' 'would foster' 'is set out in'
#  'is set out against' 'was estimated for' 'is detailed in'
#  'can be used to decide on' 'aim to raise' 'need to be drawn after'
#  'should be aligned to' 'shows' 'epitomises' 'enables Bengaluru to seek'
#  'is located in' 'first set up base in' 'moved base to' 'erected'
#  'were erected in' 'share' 'makes a connection with' 'has Direction'
#  'has Population (2011)' 'has Population decadal growth %'
#  'has Area (sq km)' 'has Population density (2011)' 'has Buildings (2014)'
#  'has HH Census (2011)' 'has Estimated Builtup area (2014)'
#  'has Property tax (2014-15)' 'has Road length (kms)/Sq. Kms'
#  'has DWCC (2014)' 'has Open spaces/Area %' 'has Police stations'
#  'has Bus stops' 'has HHs with UGD (2011) (%)'
#  'has HHs with Piped water supply (2011) (%)' 'is an argument against'
#  'is implicitly assumed to be dependent on' 'is shaped by'
#  'cannot be considered' 'is unlikely to have visualised' 'is driven by'
#  'opined that' 'would provide' 'is a recommendation for' 'will help build'
#  'will help sustain' 'will help nurture' 'revolve around' 'is proposed as'
#  'is proposed to be' 'would be supported by'
#  "would support Mayor's council in executing" 'is detrimental to'
#  'is favored to be' 'would occur at the time of'
#  'could face challenges if' 'could overcome' 'will act as precursor to'
#  'has been considered by' 'is elected by' 'is in sync with'
#  'is less preferable than' 'should be rationalised to'
#  'role is focused on' 'are needed to manage' 'are needed in' 'should have'
#  'manages about' 'contains' 'will be in charge of' 'deliver on'
#  'must bring together' 'are proposed for' 'are headed by' 'consist of'
#  'is an important activity proposed at' 'involves dumping waste from'
#  'involves dumping waste in' 'should be predominantly managed within'
#  'should be managed within' 'need to forge arrangements with'
#  'take waste on' 'are convened by' 'needs to have' 'should include'
#  'constituency falls within' 'would help resolve' 'can take stock of'
#  'can take up issues at' 'are expected to play a role in'
#  'expect MLAs to fix' 'give MLAs a handle on'
#  'provide a forum for MLAs to provide' 'derive from' 'cover subjects of'
#  'cover' 'are undertaken at' 'is the' 'has undertaken' 'set out'
#  'is a key activity at' 'will specify' 'will put in place'
#  'will work only if there is' 'takes responsibility for' 'is a cause of'
#  'has impacted' 'is strongly advocated on' 'have voiced concerns about'
#  'are best executed on' 'is a complaint of' 'will have place for'
#  'will allow for' 'are drawn' 'involve' 'is anchored in' 'is anchored at'
#  'is run as' 'has scope for' 'is ideally' 'examined' 'has area of'
#  'have area of' 'do not follow' 'consists of'
#  'was considered most appropriate for' 'is anchored under'
#  'will be headed initially by' 'has had a major role in'
#  'should go in for' 'has no' 'will be needed to enable'
#  'will subsequently be' 'are through' 'are members of' 'are experts about'
#  'help coordinate' 'will undertake' 'will perform' 'will encompass'
#  'will manage' 'are in the nature of' 'currently attempt to' 'span'
#  'is a key activity of' 'can report to' 'need to work in tandem with'
#  'include integrating activities of' 'builds' 'is much more than' 'can be'
#  'can be run as' 'should be at' 'looks out for' 'houses'
#  'are almost contiguous to' 'is to coordinate plans of' 'should remain'
#  'has been notified for' 'has held' 'is suggested to be notified as'
#  'build on the suggestions of' 'are laid out in' 'would be a'
#  'would be within' 'exhibit' 'will grow to become'
#  'need to be brought under' 'could be designated as'
#  'could be grouped with' 'have seen' 'can no longer be governed through'
#  'end up being' 'result in' 'is based on the assumption that'
#  'are designated as' 'are governed under' 'are situated within' 'inhabit'
#  'are not integrated into' 'are not established as' 'is full of'
#  'will need to be' 'is the result of' 'were outside the limits of']
#
# Number of unique subjects:
# 798
#
# Number of unique objects:
# 1383

# %% [markdown]
# ## Load embeddings and triplet data
#
# ### Subtask:
# Load the embeddings (likely from the Chroma DB as you've been working with it) and your triplet data into your environment.

# %% [markdown]
# ## Design the querying strategy
#
# ### Subtask:
# Decide how you want to combine vector search and knowledge graph information. Common strategies include:
#     * **Retrieve then Augment**: Perform vector search first to get relevant text chunks, then use the triplets to augment these chunks with related information.
#     * **Augment then Retrieve**: Use the triplets to expand the query or initial context, then perform vector search on the augmented query/context.
#     * **Hybrid Search**: Develop a method to simultaneously search both the vector space and the knowledge graph, potentially ranking results based on a combination of similarity and graph properties.

# %% [markdown]
# **Reasoning**:
# Analyze the available data and consider the strengths and weaknesses of each querying strategy to select the most suitable one. Based on the analysis, clearly describe the chosen strategy and outline the general steps for implementation.

# %%
# Analyze the available data: df_triplets and results
print("Analysis of df_triplets (Knowledge Graph):")
display(df_triplets.info())
display(df_triplets.head())
print("\nAnalysis of results (Vector Database Search Results):")
# Assuming 'results' is a dictionary from a Chroma DB query
# It likely contains 'documents', 'metadatas', and 'distances'
if 'documents' in results:
    print(f"Number of documents retrieved: {len(results['documents'][0])}")
    print("Sample document:")
    print(results['documents'][0][0][:200] + "...") # Print first 200 chars of the first doc
if 'metadatas' in results:
    print("Sample metadata:")
    print(results['metadatas'][0][0])
if 'distances' in results:
    print("Sample distance:")
    print(results['distances'][0][0])

# Consider the strengths and weaknesses of each querying strategy
print("\nConsidering Querying Strategies:")
print("1. Retrieve then Augment:")
print("   - Strengths: Simple to implement, leverages existing vector search capabilities, KG adds context to retrieved text.")
print("   - Weaknesses: Might miss relevant information only present in the KG if not retrieved by vector search, potential for disconnected information if KG links are not directly related to retrieved text.")
print("2. Augment then Retrieve:")
print("   - Strengths: Expands the initial query/context using KG, potentially leading to a more comprehensive vector search.")
print("   - Weaknesses: Query expansion can be complex, might introduce noise if KG augmentation is not precise, relies heavily on the quality of KG relationships for query expansion.")
print("3. Hybrid Search:")
print("   - Strengths: Can potentially leverage the strengths of both approaches, allows for more sophisticated ranking based on both similarity and graph structure.")
print("   - Weaknesses: Most complex to implement, requires careful design of the ranking function and integration mechanism.")

# Select the most suitable querying strategy
# Given that we have retrieved relevant text chunks using vector search ('results')
# and a KG ('df_triplets') that can provide structured relationships and context,
# the "Retrieve then Augment" strategy appears to be a good starting point.
# It allows us to first identify potentially relevant text segments via vector similarity
# and then enrich these segments with related facts and entities from the knowledge graph.
# This approach is generally simpler to implement initially compared to hybrid methods
# and directly uses the output of the previous vector search step.

chosen_strategy = "Retrieve then Augment"
print(f"\nChosen Strategy: {chosen_strategy}")

# Justify the choice and outline implementation steps
print("\nJustification:")
print(f"The '{chosen_strategy}' strategy is chosen because it directly utilizes the results from the prior vector search step. It is a practical approach to integrate the knowledge graph by using it to enrich and provide additional context to the text snippets already identified as relevant through embedding similarity. This allows the RAG system to provide more detailed and connected answers by drawing on both the textual content and the structured relationships in the knowledge graph.")

print("\nGeneral Steps for Implementing 'Retrieve then Augment':")
print("1. Perform an initial vector search based on the user query to retrieve relevant text chunks (already done, results are in 'results').")
print("2. For each retrieved text chunk, extract key entities or concepts.")
print("3. Use the extracted entities/concepts to query the knowledge graph (df_triplets) to find related triplets.")
print("4. Augment the retrieved text chunks with the relevant information found in the knowledge graph.")
print("5. Pass the augmented text (original text + KG information) to a language model to generate the final response.")
# Out:
# Analysis of df_triplets (Knowledge Graph):
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1498 entries, 0 to 1497
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   subject   1498 non-null   object
#  1   relation  1498 non-null   object
#  2   object    1498 non-null   object
# dtypes: object(3)
# memory usage: 35.2+ KB
# None
#                               subject                   relation  \
# 0  Bruhat Bengaluru Mahanagara Palike                  published
# 1                 Senior IAS officers               appointed as
# 2      Financial and Technical powers               delegated to
# 3                    Zonal Committees                 formed for
# 4                           225 wards  formed in accordance with
#
#                                        object
# 0               Performance Report of 2024-25
# 1                         Zonal Commissioners
# 2     Zonal Commissioners and other officials
# 3  administration and management of 225 wards
# 4                             BBMP Act - 2020
# Analysis of results (Vector Database Search Results):
# Number of documents retrieved: 5
# Sample document:
# Investment Opportunities
#
# Name of the Project
#
#
#
# Construction of 221 public toilets in Bengaluru City
#
# Construction of Skywalks in Bengaluru City
#
# Redevelopment of Existing Markets in Bengaluru City
# ...
# Sample metadata:
# None
# Sample distance:
# 0.5901906490325928
#
# Considering Querying Strategies:
# 1. Retrieve then Augment:
#    - Strengths: Simple to implement, leverages existing vector search capabilities, KG adds context to retrieved text.
#    - Weaknesses: Might miss relevant information only present in the KG if not retrieved by vector search, potential for disconnected information if KG links are not directly related to retrieved text.
# 2. Augment then Retrieve:
#    - Strengths: Expands the initial query/context using KG, potentially leading to a more comprehensive vector search.
#    - Weaknesses: Query expansion can be complex, might introduce noise if KG augmentation is not precise, relies heavily on the quality of KG relationships for query expansion.
# 3. Hybrid Search:
#    - Strengths: Can potentially leverage the strengths of both approaches, allows for more sophisticated ranking based on both similarity and graph structure.
#    - Weaknesses: Most complex to implement, requires careful design of the ranking function and integration mechanism.
#
# Chosen Strategy: Retrieve then Augment
#
# Justification:
# The 'Retrieve then Augment' strategy is chosen because it directly utilizes the results from the prior vector search step. It is a practical approach to integrate the knowledge graph by using it to enrich and provide additional context to the text snippets already identified as relevant through embedding similarity. This allows the RAG system to provide more detailed and connected answers by drawing on both the textual content and the structured relationships in the knowledge graph.
#
# General Steps for Implementing 'Retrieve then Augment':
# 1. Perform an initial vector search based on the user query to retrieve relevant text chunks (already done, results are in 'results').
# 2. For each retrieved text chunk, extract key entities or concepts.
# 3. Use the extracted entities/concepts to query the knowledge graph (df_triplets) to find related triplets.
# 4. Augment the retrieved text chunks with the relevant information found in the knowledge graph.
# 5. Pass the augmented text (original text + KG information) to a language model to generate the final response.

# %% [markdown]
# ## Implement the integration logic
#
# ### Subtask:
# Implement the chosen querying strategy ("Retrieve then Augment") by writing code to:
#     * Query the Chroma DB to retrieve relevant text chunks.
#     * Query or traverse your triplet data based on entities found in the query or retrieved text.
#     * Combine the information from the vector search and the knowledge graph according to your strategy.

# %% [markdown]
# **Reasoning**:
# Implement the 'Retrieve then Augment' strategy by defining a function that queries the Chroma DB, identifies entities, queries the triplets DataFrame, and augments the retrieved text chunks.

# %%
import re

def augment_with_triplets(query, results, df_triplets):
    """
    Augments retrieved text chunks from Chroma DB with related triplets from a DataFrame.

    Args:
        query (str): The user query (not directly used for retrieval here, but for context).
        results (dict): The results from the Chroma DB query, containing 'documents'.
        df_triplets (pd.DataFrame): DataFrame containing knowledge graph triplets.

    Returns:
        list: A list of augmented text chunks.
    """
    augmented_chunks = []

    # Ensure 'documents' key exists and is not empty
    if 'documents' not in results or not results['documents']:
        print("Warning: No documents found in Chroma DB results.")
        return []

    # Assuming results['documents'] is a list of lists, take the first inner list
    retrieved_documents = results['documents'][0]

    for doc in retrieved_documents:
        augmented_text = doc

        # Simple entity identification: Look for words/phrases in triplets
        # This is a basic approach; a more sophisticated method would use NER
        potential_entities = set()
        for index, row in df_triplets.iterrows():
            subject = str(row['subject'])
            object_ = str(row['object'])

            # Use regex to find potential entities (whole words/phrases) in the document
            # Add word boundaries \b to ensure we match whole words/phrases
            if re.search(r'\b' + re.escape(subject) + r'\b', doc, re.IGNORECASE):
                potential_entities.add(subject)
            if re.search(r'\b' + re.escape(object_) + r'\b', doc, re.IGNORECASE):
                potential_entities.add(object_)

        related_triplets_text = ""
        if potential_entities:
            related_triplets_text += "\n\nRelated Information from Knowledge Graph:\n"
            for entity in potential_entities:
                # Find triplets where the entity is subject or object
                entity_triplets = df_triplets[(df_triplets['subject'].str.contains(entity, case=False, na=False)) |
                                              (df_triplets['object'].str.contains(entity, case=False, na=False))]

                for index, row in entity_triplets.iterrows():
                    related_triplets_text += f"- {row['subject']} {row['relation']} {row['object']}\n"

        augmented_text += related_triplets_text
        augmented_chunks.append(augmented_text)

    return augmented_chunks

# Example usage (assuming 'query' is defined elsewhere)
# query = "Tell me about the Bruhat Bengaluru Mahanagara Palike"
# augmented_results = augment_with_triplets(query, results, df_triplets)
# for i, chunk in enumerate(augmented_results):
#     print(f"--- Augmented Chunk {i+1} ---")
#     print(chunk)
#     print("\n")

print("Function 'augment_with_triplets' defined.")
# Out:
# Function 'augment_with_triplets' defined.

# %% [markdown]
# **Reasoning**:
# Test the implemented `augment_with_triplets` function with the available `results` and `df_triplets` to demonstrate its functionality and complete the subtask.

# %%
# Define a sample query for testing
sample_query = "What is the role of Zonal Commissioners?"

# Call the function with the sample query, existing results, and df_triplets
augmented_chunks_example = augment_with_triplets(sample_query, results, df_triplets)

# Display the augmented chunks
for i, chunk in enumerate(augmented_chunks_example):
    print(f"--- Augmented Chunk {i+1} ---")
    print(chunk)
    print("\n")
# Out:
# --- Augmented Chunk 1 ---
# Investment Opportunities
#
# Name of the Project
#
#
#
# Construction of 221 public toilets in Bengaluru City
#
# Construction of Skywalks in Bengaluru City
#
# Redevelopment of Existing Markets in Bengaluru City
#
# Redevelopment of Commercial Complex at Indiranagar,
# Bengaluru
#
# Redevelopment of Commercial Complex at Vijayanagar,
# Bengaluru
#
# Development of Animation, Visual Effects, Gaming and
#
# 29 comics (AVGC Lab)
#
# fo)
#
# Development of Digital Media City
#
# i]
#
# Development of LEGO Theme Park at Bengaluru.
#
# i)
#
# Development of Disney Land Theme Park at Bengaluru
#
# Development of Cruise Dinner Project at Halasuru Lake,
# Bengaluru
#
# IN)
# aN
#
# i]
# wo
#
# Development of Snow Park in Bengaluru
#
# Development of Arts & Crafts Village in Bengaluru
#
# i}
# ron)
#
# i}
# NI
#
# Development of Bengaluru Eye
#
# IK 2016 | BENGALURU URBAN
#
# Sector
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Industrial
# Infrastructure -IT
# Parks
#
# Industrial
# Infrastructure -IT
# Parks
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# NA
#
# 335
#
# 40
#
# 26
#
# 782
#
# 62
#
# 100
#
# 40
#
# 43
#
# NA
#
# NA
#
# 56
#
# 130
#
# NA
#
# Agency
#
# BBMP
#
# BBMP
#
# BBMP
#
# BDA
#
# BDA
#
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
#
#
# Status
#
# Conceptualization
#
# Conceptualization
#
# Conceptualization
#
# Bidding Stage/
# DPR completed
#
# Conceptualization
#
# DPR under
# preparation
#
# DPR under
# preparation
#
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
#
# Related Information from Knowledge Graph:
# - Survey of 166 lakes is completed
# - actual boundaries need to be drawn after ward delimitation exercise is completed
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - 43 wards have a population of greater than 50,000
# - MC 3 has Population decadal growth % 43
# - Municipal Corporation functions derive from Article 243-W of the Twelfth Schedule of the Constitution
# - An Information Technology (IT) Cell has been operationalized by BBMP
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - Information Technology (IT) Cell is equipped with robust systems and mechanism
# - A separate helpline has been opened for assisting information /clarifications / complaints regarding e-khatha process
# - Advertisement Management Software has been developed by Information Technology Section (BBMP)
# - Information from Artificial Intelligence (AI) software will be integrated with BBMP’s existing Sahaaya Software
# - Information from Artificial Intelligence (AI) software will be integrated with Integrated Command and Control Center (ICCC)
# - CAC's official website serves as a central hub for information dissemination about CAC activities
# - CAC's official website serves as a central hub for information dissemination about CAC meetings
# - Research teams of experts compiled information
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
# - Comprehensive solid waste management is part of Brand Bengaluru concept
# - Bruhat Bengaluru Mahanagara Palike has a newly formed health & sanitation wing
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - Pourakarmikas contribute to sanitation efforts of Bengaluru city
# - Government approved implementation of Arogya Bengaluru Scheme
# - Arogya Bengaluru Scheme is under Brand Bengaluru campaign
# - Arogya Bengaluru Scheme will lead to up-gradation of 19 hospitals
# - Arogya Bengaluru Scheme will boost diagnostics facilities
# - Arogya Bengaluru Scheme will provide 60 plus tests free of cost
# - Arogya Bengaluru Scheme will provide dental services at 26 new points
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - 1,13,000 saplings planted in Bengaluru
# - Five tree parks being developed under "Brand Bengaluru -Green Bengaluru" initiative
# - Lakes of Bengaluru have major historical value
# - Lakes of Bengaluru have major cultural value
# - Lakes of Bengaluru enhance livability of the city
# - Rs.35 crores allocated under “Brand Bengaluru -Green Bengaluru” grant
# - Bengaluru Climate Action Plan (BCAP) is associated with Climate Action Cell (CAC)
# - Bengaluru Climate Action Cell (CAC) commenced operations in February 2024
# - Bengaluru Climate Action Cell (CAC) marks a pivotal moment in city's commitment to addressing climate change
# - Bengaluru Climate Action Cell (CAC) has primary objective to facilitate implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action Cell (CAC) has primary objective to spearhead implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action and Resilience Plan (BCAP) is implemented within jurisdictional limits of Bruhat Bengaluru Mahanagara Palike
# - Fellowship program aims to bolster implementation of Bengaluru's climate action initiatives
# - The Blue-Green Awards have been instituted to recognize individuals making a significant impact in advancing Bengaluru's climate action aspirations
# - The Blue-Green Awards have been instituted to recognize organizations making a significant impact in advancing Bengaluru's climate action aspirations
# - CAC demonstrated a comprehensive approach to driving Bengaluru's climate action
# - CAC demonstrated a collaborative approach to driving Bengaluru's climate action
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - survey of existing 6819 BBMP properties has begun under Section 136 (4) of the Bruhat Bengaluru Mahanagara Palike Act - 2020
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - "Sancharyukta Bengaluru" works have an approved cost of Rs.200 crores
# - tenders have been invited for "Sancharyukta Bengaluru" works worth Rs.47 crores
# - an estimate has been prepared for remaining "Sancharyukta Bengaluru" works worth Rs.53 crores
# - "Sancharyukta Bengaluru" road works will be executed after acquisition of land from the Defense Department
# - Rs.50 crores have been provided for widening of RMP roads under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.50 crores have been provided for construction of RMP road under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.200 crores have been allocated for Bengaluru Urban Tunnel Project
# - Bengaluru Urban Tunnel Project is part of Bengaluru Urban Integrated Mobility Project
# - Rs.50 crores (for Bengaluru Urban Tunnel Project) is expected to be utilized in the project
# - tenders have been invited for development of Padarayanapura road under Sugama Sanchara Bengaluru
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - BRUHAT BENGALURU MAHANAGARA PALIKE has a PERFORMANCE REPORT OF 2024-25
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Vibrant Bengaluru theme is under Brand Bengaluru Campaign
# - Vibrant Bengaluru theme is for the project Decorative Electrification Project
# - Chapter 2 is titled Bengaluru: Karnataka's prime urban centre
# - Bengaluru was known as ‘Garden City’
# - Bengaluru had abundance of greenery
# - Young minds made Bengaluru a software capital of the world
# - The metropolitan city (Bengaluru) registered highest growth rate of 44.6%
# - Bengaluru’s urban management has come under severe criticism
# - The report establishes a need for urgent structural changes in Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - Bengaluru Metropolitan Area (BMA) is projected to have a population of 20 million by 2040
# - Greater Bangalore Authority ensures Bengaluru remains as one city governance
# - Expert Committee's mandate focused on improving quality of life for all citizens in Bengaluru
# - State has overriding influence over Bengaluru
# - Bengaluru has a weak, one-year 'titular' mayor system
# - The garbage problem in Bengaluru has been festering for over three years
# - The garbage problem in Bengaluru is without a positive resolution
# - Existing infirmities are holding back Bengaluru
# - Bengaluru is prevented from realising its potential as the best city in India
# - Bengaluru is prevented from realising its potential as one of the truly liveable global cities in the world
# - The city (Bengaluru) needs to be an engine of economic growth
# - The city (Bengaluru) needs to be creating livelihoods
# - The city (Bengaluru) needs to be attracting investments
# - Realising the holistic vision for Bengaluru will call for political will
# - Realising the holistic vision for Bengaluru will call for administrative support
# - The Committee recommends a holistic structure for managing Bengaluru
# - A holistic structure for managing Bengaluru is guided by constitutional principles
# - Recommendations provide for the Greater Bengaluru Authority (GBA) as a Local Planning Authority (LPA)
# - The suggested architecture for managing Bengaluru promotes Political Devolution
# - The suggested architecture for managing Bengaluru promotes Decentralised Accountability
# - The suggested architecture for managing Bengaluru supports co-existence of larger Metropolitan governance structures
# - The suggested architecture for managing Bengaluru supports protecting the devolved powers at the lower levels
# - Metropolitan governance structures aim to protect and reinforce brand Bengaluru
# - The suggested architecture for managing Bengaluru includes ‘Watch dog’ mechanisms
# - A Greater Bengaluru Finance Commission is for fair and equitable distribution of resources
# - A Greater Bengaluru Finance Commission is for problem resolution
# - A Greater Bengaluru Services Ombudsman allows citizens to make their case for better civic services
# - A Municipalisation Committee is housed within the Greater Bengaluru Authority
# - The Committee suggested a 3 tier governance framework for Bengaluru
# - A 3 tier governance framework for Bengaluru includes Ward, Municipal Corporation, Greater Bengaluru Authority (GBA)
# - The current Bengaluru Metropolitan Area has a footprint of 1,307 sq kms
# - Bengaluru today has an inner core (within Outer Ring Road)
# - Bengaluru today has an outer periphery
# - Proposed Greater Bengaluru Finance Commission should set out a basis for financial devolution to the ward
# - Bengaluru's population is projected to be over 20 million by 2040
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - Nearly half of Bengaluru's population lives in wards in the outer areas
# - Bengaluru has a population of 10 million
# - Bengaluru has an area of 709.5 sq kms
# - No city with Bengaluru's population and area operates as a single Corporation entity
# - Bengaluru's growth has been rapid since 2001
# - Bengaluru's growth is projected to continue until 2040
# - Bengaluru's growth has occurred beyond the Outer Ring Road
# - 5 Corporation solution balanced various areas of Bengaluru
# - 5 Corporation solution kept intact essential character of Bengaluru
# - 5 Corporation model epitomises a Bengaluru aligned to its historical roots
# - Kempegowda is Bengaluru’s founder
# - Kempegowda II moved base to Bengaluru
# - 4 pillars represent boundaries of Bengaluru
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - Brand Bengaluru is shaped by its people
# - Brand Bengaluru is shaped by its ethos
# - Brand Bengaluru is shaped by its culture
# - Brand Bengaluru is shaped by its vibrancy
# - Brand Bengaluru is shaped by its promise
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - Greater Bengaluru Authority is a recommendation for Bengaluru
# - Greater Bengaluru Authority will help build brand Bengaluru
# - Greater Bengaluru Authority will help sustain brand Bengaluru
# - Greater Bengaluru Authority will help nurture brand Bengaluru
# - directly elected Mayor will act as precursor to directly elected Metropolitan Mayor of the Greater Bengaluru Authority
# - Tier 2 and Tier 3 arrangements will work only if there is a Greater Bengaluru layer (Tier 1)
# - Greater Bengaluru layer (Tier 1) integrates all civic activities
# - Greater Bengaluru layer (Tier 1) takes responsibility for planning and administration of Bengaluru metropolitan activities
# - Lack of attention and future planning for the extended region is a cause of Bengaluru’s current woes
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Greater Bengaluru Authority (GBA) is the apex body
# - Greater Bengaluru Authority (GBA) is strongly advocated on multiple counts
# - Nearly all stakeholders consulted have voiced concerns about protecting the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about nurturing the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about growing the Bengaluru brand
# - Greater Bengaluru Authority (GBA) will ensure all activities in the metropolitan area are in sync with building brand Bengaluru
# - Lack of inter-agency coordination due to organisation silos is a complaint of Bengaluru citizens
# - Economic Development Agency has scope for Bengaluru to be at the forefront on city economy innovation
# - Footprint of the GBA is ideally Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
# - proposed Greater Bengaluru Authority will be headed initially by Chief Minister
# - Greater Bengaluru Authority should go in for a directly elected ‘Metropolitan Mayor’
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - GBA includes 5 Bengaluru City MLAs
# - Bengaluru City MLAs are members of relevant Municipal Corporation
# - Greater Bengaluru Finance Commission is for fair and equitable distribution
# - Bengaluru needs a planning body
# - A planning body looks out for development activities on Bengaluru's outskirts
# - Several urban local bodies are almost contiguous to Bengaluru
# - Bengaluru is one city
# - Nodal officer resolves grievances of the public
# - Public can view their e-Khata online
# - Public can check and correct errors in their e-khatas
# - Cultural programs were organized on Republic days
# - Public Notice is issued for any objections or suggestions regarding the proposed construction of the sky deck in Hemmigepura
# - Scrutiny of received public objections and suggestions are under process
# - White-topped roads received positive feedback and public appreciation for its effectiveness
# - Pipe ducts will ensure a systematic and public-friendly footpath
# - Need for comprehensive solid waste management is based on feedback from public, experts and various organizations
# - 160 existing public toilets are being upgraded
# - 204 new public toilets are being constructed under 5 packages
# - Work orders have been issued for 3 packages (of public toilet construction)
# - Remaining 2 packages (for public toilet construction) are at tender approval stage
# - Avenue Plantation initiative received support from public
# - Hi-Tech Nurseries will raise seedlings for public distribution
# - Inspection reports available for public view
# - Capacity building workshops covered topics including resilient, inclusive, safe and accessible public spaces
# - Corporate Social Responsibility (CSR) Convening was conducted for engagement of corporates in public works
# - CAC's approach involved implementation of targeted public awareness campaigns
# - Public Relations Department publicizes the importance of each service and project implemented by BBMP
# - Public Relations Department publicizes to citizens
# - Public Relations Department uses various media platforms
# - Public Relations Department publicizes property tax services
# - Public Relations Department publicizes OTS services
# - Public Relations Department publicizes E-khata issuance
# - Public Relations Department publicizes various treatment facilities at Namma clinics
# - Public Relations Department publicizes Solid Waste Management programs
# - Public Relations Department publicizes Welfare and other programs
# - Rs.25 crores was kept for junction improvement and beautification of public places
# - Expert Committee set up teams for public finance
# - specialized economic development agency can be run as public-private partnership
# - BBMP is currently maintaining about 1,280 parks
# - A grant of Rs.83 crores is for maintenance of parks and median
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - The decision to keep parks open aims to make parks more accessible to all citizens
# - Works worth Rs. 40 crores are under progress for development of new parks
# - Works worth Rs. 40 crores are under progress for up-gradation of existing parks
# - Works worth Rs. 40 crores are under progress for constructing water harvesting and storage structures in parks
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Works for development of 14 New Parks are under progress
# - More than 750 percolation pits have been constructed in parks
# - Construction of more than 750 percolation pits aims to improve ground water table in parks
# - Around Rs. 32 crores are being spent to fence and secure 30 parks
# - Works to fence and secure parks are under progress in 18 locations
# - Hasiru Mitra aims to monitor maintenance of parks
# - Agencies appointed by BBMP maintain parks
# - Citizens can visit parks inspection reports online
# - Hasiru Mitra - Volunteer helps in inspecting and monitoring maintenance of parks
# - 48 parks and medians are given for adoption under CIPC policy
# - Major plantations done in parks
# - Five tree parks being developed under "Brand Bengaluru -Green Bengaluru" initiative
# - Five tree parks are based on different themes
# - Development of five tree parks costs Rs. 11 crores
# - Nodal officer resolves grievances of the public
# - Public can view their e-Khata online
# - Public can check and correct errors in their e-khatas
# - Cultural programs were organized on Republic days
# - Public Notice is issued for any objections or suggestions regarding the proposed construction of the sky deck in Hemmigepura
# - Scrutiny of received public objections and suggestions are under process
# - White-topped roads received positive feedback and public appreciation for its effectiveness
# - Pipe ducts will ensure a systematic and public-friendly footpath
# - Need for comprehensive solid waste management is based on feedback from public, experts and various organizations
# - 160 existing public toilets are being upgraded
# - 204 new public toilets are being constructed under 5 packages
# - Work orders have been issued for 3 packages (of public toilet construction)
# - Remaining 2 packages (for public toilet construction) are at tender approval stage
# - Avenue Plantation initiative received support from public
# - Hi-Tech Nurseries will raise seedlings for public distribution
# - Inspection reports available for public view
# - Capacity building workshops covered topics including resilient, inclusive, safe and accessible public spaces
# - Corporate Social Responsibility (CSR) Convening was conducted for engagement of corporates in public works
# - CAC's approach involved implementation of targeted public awareness campaigns
# - Public Relations Department publicizes the importance of each service and project implemented by BBMP
# - Public Relations Department publicizes to citizens
# - Public Relations Department uses various media platforms
# - Public Relations Department publicizes property tax services
# - Public Relations Department publicizes OTS services
# - Public Relations Department publicizes E-khata issuance
# - Public Relations Department publicizes various treatment facilities at Namma clinics
# - Public Relations Department publicizes Solid Waste Management programs
# - Public Relations Department publicizes Welfare and other programs
# - Rs.25 crores was kept for junction improvement and beautification of public places
# - Expert Committee set up teams for public finance
# - specialized economic development agency can be run as public-private partnership
# - 30,756 dogs have been neutered as part of animal birth control program
# - MC 1 has Population density (2011) 7,568 per sq.km
# - MC 1 has HHs with UGD (2011) (%) 56.4
# - MC 3 has DWCC (2014) 56
# - MC 4 has Property tax (2014-15) 456.1 Rs. crores
# - MC 5 has Buildings (2014) 256,717
# - BDA is a silo 'parastatal'
# - A Municipalisation Committee is housed in the BDA
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - BMA footprint consists of BBMP + BDA
# - Zilla Parishad representatives are from BDA area
# - Municipalisation Committee is for orderly transition of rural to urban areas in BDA
# - BDA can report to GBA
# - MPC has been notified for the BDA area
# - About 25 villages are in the BDA area
# - About 25 villages in the BDA area exhibit urban characteristics
# - The BDA area is full of urban fragments
# - Revenue collected from Premium FAR charges will be utilized for infrastructure development
# - A one-month pilot project was implemented to identify issues in civic infrastructure
# - AI Based video feed analysis is for identification and analysis of civic infrastructure issues
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Unplanned growth led to huge infrastructure deficiencies
# - Greater Bangalore Authority/Council is responsible for infrastructure development
# - Expert Committee's mandate focused on Access to quality infrastructure and services
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - Wards with historical infrastructure deficiencies would need additional intervention through proposed GBA
# - inability to reorganise ward wise is due to operation logistics, infrastructure, and costs
# - One key objective of amalgamation was to provide infrastructure in outlying areas
# - Infrastructure provision in outlying areas has not been achieved as an objective of amalgamation
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - infrastructure availability was estimated for these 5 Corporation areas
# - infrastructure availability is detailed in Chapter 3
# - infrastructure availability is detailed in Appendix IV
# - estimated infrastructure availability can be used to decide on investment decisions
# - investment decisions aim to raise infrastructure quotient in under developed wards
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Civic requirements executed on a larger scale include major road infrastructure
# - Planning functions will encompass close inter-linkages between land use plans, mobility, infrastructure, economic development plans
# - GBA will manage Mega Infrastructure projects
# - Mega Infrastructure projects span the city
# - Mega Infrastructure projects include major arterial roads
# - Mega Infrastructure projects include storm water drains
# - Mega Infrastructure projects include flyovers
# - Mega Infrastructure projects include bus rapid transit systems
# - 225 wards formed in accordance with BBMP Act - 2020
# - A draft prepared for amendment of BBMP Cadre and Recruitment Rules
# - The draft (BBMP Cadre and Recruitment Rules amendment) will be submitted to the Government
# - BBMP commenced recruitment process of Direct Payment System Pourakarmikas
# - BBMP is taking action to review and implement recommendations of Administrative Reforms Commission reports
# - Corpus fund facilitates welfare of the retired employees of BBMP
# - The proposal (to establish Pensioners’ Arogya Kalyana Nidhi Scheme) received approval from Hon’ble Administrator of BBMP
# - An Information Technology (IT) Cell has been operationalized by BBMP
# - A Contactless and Faceless online e-khata system adopted by BBMP
# - BBMP achieved highest property tax collection in the country in FY 2023-24
# - BBMP recovered Rs. 1,277 crores arrears of property tax
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - BBMP (Estate Management) Rules 2024 provide for proper management of 6,818 properties
# - Rs.2,817.96 crores of Government grants have been received by BBMP till February 2025
# - BBMP's IT section implemented various softwares
# - The e-Aasthi system has been developed by BBMP's IT section
# - GIS mapping of properties in BBMP is incorporated into e-Aasthi system
# - The draft e-khata is available on BBMP e-Aasthi website
# - Court Case Management System (CCMS) is implemented in BBMP
# - Advertisement Management Software has been developed by Information Technology Section (BBMP)
# - Fix Pothole Software operates in BBMP areas
# - AI Based video feed analysis operates in BBMP
# - 250 dash cameras shall be installed on BBMP vehicles
# - Information from Artificial Intelligence (AI) software will be integrated with BBMP’s existing Sahaaya Software
# - BBMP online service is being integrated with EODB
# - BBMP’s various softwares are being integrated under EODB
# - Karnataka Government has mandated that BBMP services be provided online
# - 23,341 students are studying under BBMP’s Education Department
# - BBMP’s Education Department operates 93 Nursery Schools
# - BBMP’s Education Department operates 16 Primary Schools
# - BBMP’s Education Department operates 34 High Schools
# - BBMP’s Education Department operates 19 P.U. Colleges
# - BBMP’s Education Department operates 4 Graduate Colleges
# - BBMP’s Education Department operates 2 Post Graduate Colleges
# - School Development and Monitoring Committee (SDMC) is functional in all BBMP schools
# - College Development Committees (CDC) are functional in all BBMP colleges
# - All BBMP school and college students were provided with two sets of uniform
# - All BBMP school and college students were provided with shoes and socks
# - All BBMP school and college students were provided with notebooks
# - All BBMP school and college students were provided with textbooks
# - All BBMP school and college students were provided with sweaters
# - All BBMP school and college students were provided with school bags
# - All BBMP school and college students were provided with a Mid-day meal
# - Age group-wise library books were provided to BBMP schools/colleges
# - Sports equipment were provided to BBMP schools/colleges
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - Pratham Education Foundation supports BBMP schools
# - Systemic change is achieved by strengthening monitoring capacities of BBMP monitoring cadre
# - The learning improvement program has been implemented in 16 primary schools under BBMP
# - The learning improvement program has been implemented in 93 nursery schools under BBMP
# - BBMP education department is procuring laboratory equipment
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - BBMP aimed to provide a better experience to BBMP school and college students
# - BBMP took BBMP school and college students on educational excursions to various historical, cultural and eco spots of Karnataka
# - BBMP has started biometric face identification and geo-fenced attendance systems
# - BBMP became the first corporation to launch the combined vaccination for street dogs for 5 diseases
# - BBMP became the first corporation to start feeding its stray dogs on pilot basis
# - Approximately 200 km of roads within the jurisdiction of the BBMP have been white-topped
# - BBMP is currently maintaining about 1,280 parks
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - Hasiru Mitra has been developed by BBMP Horticulture wing
# - BBMP Horticulture wing developed Hasiru Mitra in coordination with IT team
# - Agencies appointed by BBMP maintain parks
# - BBMP appoints agencies through tender process
# - CIPC enables stakeholders to assist BBMP
# - BBMP associated with Association for physically challenged
# - BBMP provided physiotherapy to more than 600 children
# - OPD services at BBMP’s Namma Clinics increased to average 40 out-patients per day
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - BBMP Forest wing manages trees through 30 tree canopy management teams
# - Three Hi-Tech Nurseries being established under BBMP grants
# - BBMP has in its jurisdiction 183 live lakes
# - BBMP's role is to develop lakes
# - BBMP's role is to rejuvenate lakes
# - BBMP's role is to maintain lakes
# - Kere Mitra App can be used by BBMP officials
# - BBMP officials use Kere Mitra App to monitor agencies in lake maintenance
# - BBMP officials use Kere Mitra App to supervise agencies in lake maintenance
# - BBMP lakes division protects lakes and its premises
# - BBMP lakes division coordinates with Revenue Department
# - BBMP lakes division coordinates with Survey wing
# - BBMP lakes division coordinates with BBMP zonal engineers
# - BBMP lakes division aims to identify boundaries
# - BBMP lakes division aims to demarcate boundaries
# - BBMP lakes division aims to remove encroachments
# - Boundary of 27 lakes demarcated with BBMP grant of Rs. 40 crores
# - BBMP’s CAC has taken a big step towards Climate Budgeting
# - BBMP’s CAC has taken a big step towards Monitoring Evaluation and Reporting (MER) of sector-wise actions
# - BBMP has implemented the Pension Scheme for retired DPS pourakarmikas
# - BBMP has provided sarees to 15,150 Pourakarmikas
# - BBMP has provided aprons to 15,150 Pourakarmikas
# - BBMP has provided sweaters to 15,150 Pourakarmikas
# - BBMP has provided track pants to 15,150 Pourakarmikas
# - BBMP has deployed 5 high pressure Power Jetting Road Washing Machines
# - New Advertisement Bye-law 2024 was proposed by BBMP
# - New Advertisement Bye-law facilitates BBMP to earn more revenue
# - Public Relations Department publicizes the importance of each service and project implemented by BBMP
# - BBMP properties notified in Karnataka Gazette have been uploaded to BBMP website (www.bbmp.gov.in)
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - lease amount for BBMP properties will be fixed based on guidance value
# - survey of existing 6819 BBMP properties has begun under Section 136 (4) of the Bruhat Bengaluru Mahanagara Palike Act - 2020
# - survey of existing 6819 BBMP properties uses ROVERS
# - 60% of BBMP properties of Raja Rajeshwari Nagar zone have been surveyed
# - separate Survey Wing (209 personnel) has been approved for surveying 20 lakhs private properties and 6819 BBMP properties
# - Details of the Committee's work are set out in website www.bbmprestructuring.org
# - The Committee understood current status of the Municipal Corporation (BBMP)
# - Current status of Municipal Corporation (BBMP) includes organizational structure
# - Current status of Municipal Corporation (BBMP) includes finances
# - Current status of Municipal Corporation (BBMP) includes human resources
# - Current status of Municipal Corporation (BBMP) includes delegation of powers
# - Current status of Municipal Corporation (BBMP) includes role responsibilities of Council
# - Current status of Municipal Corporation (BBMP) includes zonal offices
# - Current status of Municipal Corporation (BBMP) includes wards
# - B.S. Patil has invaluable experience and knowledge on BBMP
# - B.S. Patil served as Commissioner on BBMP on two occasions
# - Shri V. Ravichandar contributed to innovative tax reforms within BBMP
# - The Committee submitted its report on ‘BBMP Restructuring’
# - The report on ‘BBMP Restructuring’ was submitted to Govt. of Karnataka
# - B.S. Patil provided leadership for the BBMP Restructuring exercise
# - B.S. Patil provided wise counsel for the BBMP Restructuring exercise
# - B.S. Patil provided sage advice for the BBMP Restructuring exercise
# - The Expert Committee was constituted to suggest division of BBMP into smaller municipal areas
# - Villages added to BBMP lack basic amenities
# - BBMP set up lacked appropriate governance
# - BBMP set up lacked administration
# - BBMP set up lacked people capacity
# - Current setup includes BBMP
# - www.bbmprestructuring.org is a web site
# - www.bbmprestructuring.org was set up as two-way communication platform between Citizens and the Expert Committee
# - BBMP is plagued by multiple deficits
# - BBMP has Ineffective Governance and Administration
# - Standing Committees in BBMP are omnibus and ineffective
# - Standing Committees in BBMP include around 132 Councillors across 12 Committees
# - BBMP has a trust deficit
# - Inflated contract values are considered the norm at BBMP
# - Financial indiscipline is the norm at BBMP
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - Property tax payers (BBMP) are less than 50% of estimated
# - Revenue realisations (BBMP) are low
# - BBMP has poor Human resources
# - C&R (Cadre & Recruitment) Rules, 1971 govern BBMP
# - In-house employees (BBMP) lack urban expertise
# - In-house employees (BBMP) have no training
# - External resources at senior levels (BBMP) have limited capabilities
# - External resources at senior levels (BBMP) have no long term commitment to BBMP
# - External resources at senior levels (BBMP) are detrimental to developing a healthy internal culture
# - Specific job-oriented training (BBMP) is negligible
# - Induction program (BBMP) is non-existent
# - BBMP has a staff shortage of about 35% vis-à-vis sanctioned capacity
# - BBMP lacks Transparency
# - BBMP's operations and finances are shrouded in secrecy
# - Visibility on where money is spent (BBMP) is non-existent
# - MIS system (BBMP) is not in place
# - Senior officers (BBMP) are severely handicapped in taking decisions
# - Appetite for proactive disclosure (BBMP) is non-existent
# - Central Accounts Office of BBMP was not part of computerised accounting system at Zonal level
# - Financial audit (BBMP) has not occurred for over four years
# - Internal records (BBMP) are poor
# - BBMP suffers from Financial Mismanagement
# - BBMP has own revenue sources of around Rs. 1800 crores annually (including arrears)
# - BBMP had pending bills as of Apr 1, 2015 of Rs. 2,300 crores
# - BBMP had a loan of around Rs. 2,200 crores
# - BBMP had Spill over works of Rs. 3,000 crores
# - BBMP's financial situation is indicative of serious financial stress
# - Approach to haphazard urban developments on the outskirts of the BBMP area is reactive
# - The Expert Committee on BBMP Restructuring focussed on finding systemic remedies
# - The existing 198 wards are in the BBMP area of 709.5 sq kms
# - current BBMP area has a population of around 10 million
# - Committee suggests about 400 wards for current BBMP area
# - citizens expect BBMP and civic service providers to align activities at ward level
# - Current single BBMP model is unsustainable
# - Current single BBMP model is not effective currently
# - A single BBMP Commissioner finds it near impossible to effectively administer a wide populace over a large geographic area
# - BBMP currently has 8 Zonal units
# - Population within Outer Ring Road (ORR) in BBMP (2015) was approximately equal to population outside Outer Ring Road (ORR) in BBMP (2015)
# - Population in outer areas (of BBMP) is projected to increase relative to population within Outer Ring Road (ORR)
# - Current single BBMP model has 261 members
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - recommendation to make BBMP into multiple units is driven by desire to make the city more manageable
# - recommendation to make BBMP into multiple units is driven by desire to make the city more liveable
# - Current system of dumping municipal solid waste involves dumping waste in villages outside BBMP
# - Villages outside BBMP have a population of 500-1000
# - BBMP has area of 709.5 sq kms
# - BMA footprint consists of BBMP + BDA
# - The restructuring exercise should include planned municipalisation of portions of the GBA that are outside BBMP limits
# - Portions of the GBA outside BBMP limits have seen a significant rise in home construction
# - BBMP is the result of the municipalisation and absorption of earlier villages
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - The 250 meter High Sky Deck aims to promote tourism
#
#
#
# --- Augmented Chunk 2 ---
# Industry Profile
#
# - 315 Large Scale Industries with aggregated investment of INR 14793 Crore
#
# « 211Medium Scale Industries with aggregated investment of INR 1342 Crore
#
#
#
# + 74,282 small-scale industries with aggregated investment INR 41,213 Crore
#
# * World Economic Forum identified Bengaluru as the Innovation Cluster
# + Business Week placed Bengaluru among the 'Global Hot Spots of the 21* Century’
# + Bengaluru is also known as Silicon Valley and Technology Base in Asia
#
# + Bengaluru is one of the pioneers in the concept of industrial clusters with established industrial clusters
# like Whitefield, Electronics City, Peenya etc.
#
# + Peenya is the largest Industrial cluster in Asia
#
# - IT firms in Bengaluru employ about 35% of India’s pool of 1 million IT professionals and account for the
# highest IT-related exports in the country
#
# - Bengaluru is home to the biggest bio cluster in India with 137 Biotechnology companies, making it 40%
# of the total 340 such units in the country. Home to the biggest bio cluster in the Electronic City
#
# * Total 87 Fortune 500 MNCs, 2084 IT Companies and 195 BT companies are there in Bengaluru
#
# « Wellness Tourism: Bengaluru city facilitates over 6,000 patients from across the world with distinction
# of having largest number of systems of medicine approved by the WHO in asingle city
#
# + Bengaluru ranks the highest in India in the implementation and value of PPP projects
#
# *« Wheel & Axel Industry, with highest production unit in Asia
#
# Artisan Clusters:
#
# + Agarbatti, Rugs & Duries, Wood Carving, Shopping Bag/ Fancy Items, Toys and Decoration pieces, Brass
# and Copper Art Ware, Dolls from pulp, Jewellery,Metalware Grass, Leaf, Reed & Fibre, Earthier
# ware/pottery, Embroidery by hand, Printing of cloth by hand, Toys and Decoration pieces, Wood
# Furniture & Fixtures, Textile Handlooms
#
# MSME Clusters:
#
# Machine Tools, Power Loom , Electronic Goods , Readymade Garments , Light engineering, Leather
# Products
#
# Natural Resources:
# Felspar
#
# Source: DIC - Bengaluru Urban
#
# IK 2016 | BENGALURU URBAN Go
#
# Related Information from Knowledge Graph:
# - 6,819 properties have been identified
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
# - Comprehensive solid waste management is part of Brand Bengaluru concept
# - Bruhat Bengaluru Mahanagara Palike has a newly formed health & sanitation wing
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - Pourakarmikas contribute to sanitation efforts of Bengaluru city
# - Government approved implementation of Arogya Bengaluru Scheme
# - Arogya Bengaluru Scheme is under Brand Bengaluru campaign
# - Arogya Bengaluru Scheme will lead to up-gradation of 19 hospitals
# - Arogya Bengaluru Scheme will boost diagnostics facilities
# - Arogya Bengaluru Scheme will provide 60 plus tests free of cost
# - Arogya Bengaluru Scheme will provide dental services at 26 new points
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - 1,13,000 saplings planted in Bengaluru
# - Five tree parks being developed under "Brand Bengaluru -Green Bengaluru" initiative
# - Lakes of Bengaluru have major historical value
# - Lakes of Bengaluru have major cultural value
# - Lakes of Bengaluru enhance livability of the city
# - Rs.35 crores allocated under “Brand Bengaluru -Green Bengaluru” grant
# - Bengaluru Climate Action Plan (BCAP) is associated with Climate Action Cell (CAC)
# - Bengaluru Climate Action Cell (CAC) commenced operations in February 2024
# - Bengaluru Climate Action Cell (CAC) marks a pivotal moment in city's commitment to addressing climate change
# - Bengaluru Climate Action Cell (CAC) has primary objective to facilitate implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action Cell (CAC) has primary objective to spearhead implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action and Resilience Plan (BCAP) is implemented within jurisdictional limits of Bruhat Bengaluru Mahanagara Palike
# - Fellowship program aims to bolster implementation of Bengaluru's climate action initiatives
# - The Blue-Green Awards have been instituted to recognize individuals making a significant impact in advancing Bengaluru's climate action aspirations
# - The Blue-Green Awards have been instituted to recognize organizations making a significant impact in advancing Bengaluru's climate action aspirations
# - CAC demonstrated a comprehensive approach to driving Bengaluru's climate action
# - CAC demonstrated a collaborative approach to driving Bengaluru's climate action
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - survey of existing 6819 BBMP properties has begun under Section 136 (4) of the Bruhat Bengaluru Mahanagara Palike Act - 2020
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - "Sancharyukta Bengaluru" works have an approved cost of Rs.200 crores
# - tenders have been invited for "Sancharyukta Bengaluru" works worth Rs.47 crores
# - an estimate has been prepared for remaining "Sancharyukta Bengaluru" works worth Rs.53 crores
# - "Sancharyukta Bengaluru" road works will be executed after acquisition of land from the Defense Department
# - Rs.50 crores have been provided for widening of RMP roads under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.50 crores have been provided for construction of RMP road under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.200 crores have been allocated for Bengaluru Urban Tunnel Project
# - Bengaluru Urban Tunnel Project is part of Bengaluru Urban Integrated Mobility Project
# - Rs.50 crores (for Bengaluru Urban Tunnel Project) is expected to be utilized in the project
# - tenders have been invited for development of Padarayanapura road under Sugama Sanchara Bengaluru
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - BRUHAT BENGALURU MAHANAGARA PALIKE has a PERFORMANCE REPORT OF 2024-25
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Vibrant Bengaluru theme is under Brand Bengaluru Campaign
# - Vibrant Bengaluru theme is for the project Decorative Electrification Project
# - Chapter 2 is titled Bengaluru: Karnataka's prime urban centre
# - Bengaluru was known as ‘Garden City’
# - Bengaluru had abundance of greenery
# - Young minds made Bengaluru a software capital of the world
# - The metropolitan city (Bengaluru) registered highest growth rate of 44.6%
# - Bengaluru’s urban management has come under severe criticism
# - The report establishes a need for urgent structural changes in Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - Bengaluru Metropolitan Area (BMA) is projected to have a population of 20 million by 2040
# - Greater Bangalore Authority ensures Bengaluru remains as one city governance
# - Expert Committee's mandate focused on improving quality of life for all citizens in Bengaluru
# - State has overriding influence over Bengaluru
# - Bengaluru has a weak, one-year 'titular' mayor system
# - The garbage problem in Bengaluru has been festering for over three years
# - The garbage problem in Bengaluru is without a positive resolution
# - Existing infirmities are holding back Bengaluru
# - Bengaluru is prevented from realising its potential as the best city in India
# - Bengaluru is prevented from realising its potential as one of the truly liveable global cities in the world
# - The city (Bengaluru) needs to be an engine of economic growth
# - The city (Bengaluru) needs to be creating livelihoods
# - The city (Bengaluru) needs to be attracting investments
# - Realising the holistic vision for Bengaluru will call for political will
# - Realising the holistic vision for Bengaluru will call for administrative support
# - The Committee recommends a holistic structure for managing Bengaluru
# - A holistic structure for managing Bengaluru is guided by constitutional principles
# - Recommendations provide for the Greater Bengaluru Authority (GBA) as a Local Planning Authority (LPA)
# - The suggested architecture for managing Bengaluru promotes Political Devolution
# - The suggested architecture for managing Bengaluru promotes Decentralised Accountability
# - The suggested architecture for managing Bengaluru supports co-existence of larger Metropolitan governance structures
# - The suggested architecture for managing Bengaluru supports protecting the devolved powers at the lower levels
# - Metropolitan governance structures aim to protect and reinforce brand Bengaluru
# - The suggested architecture for managing Bengaluru includes ‘Watch dog’ mechanisms
# - A Greater Bengaluru Finance Commission is for fair and equitable distribution of resources
# - A Greater Bengaluru Finance Commission is for problem resolution
# ...
# - Bengaluru Urban Tunnel Project is part of Bengaluru Urban Integrated Mobility Project
# - Rs.50 crores (for Bengaluru Urban Tunnel Project) is expected to be utilized in the project
# - tenders have been invited for development of Padarayanapura road under Sugama Sanchara Bengaluru
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - BRUHAT BENGALURU MAHANAGARA PALIKE has a PERFORMANCE REPORT OF 2024-25
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Vibrant Bengaluru theme is under Brand Bengaluru Campaign
# - Vibrant Bengaluru theme is for the project Decorative Electrification Project
# - Chapter 2 is titled Bengaluru: Karnataka's prime urban centre
# - Bengaluru was known as ‘Garden City’
# - Bengaluru had abundance of greenery
# - Young minds made Bengaluru a software capital of the world
# - The metropolitan city (Bengaluru) registered highest growth rate of 44.6%
# - Bengaluru’s urban management has come under severe criticism
# - The report establishes a need for urgent structural changes in Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - Bengaluru Metropolitan Area (BMA) is projected to have a population of 20 million by 2040
# - Greater Bangalore Authority ensures Bengaluru remains as one city governance
# - Expert Committee's mandate focused on improving quality of life for all citizens in Bengaluru
# - State has overriding influence over Bengaluru
# - Bengaluru has a weak, one-year 'titular' mayor system
# - The garbage problem in Bengaluru has been festering for over three years
# - The garbage problem in Bengaluru is without a positive resolution
# - Existing infirmities are holding back Bengaluru
# - Bengaluru is prevented from realising its potential as the best city in India
# - Bengaluru is prevented from realising its potential as one of the truly liveable global cities in the world
# - The city (Bengaluru) needs to be an engine of economic growth
# - The city (Bengaluru) needs to be creating livelihoods
# - The city (Bengaluru) needs to be attracting investments
# - Realising the holistic vision for Bengaluru will call for political will
# - Realising the holistic vision for Bengaluru will call for administrative support
# - The Committee recommends a holistic structure for managing Bengaluru
# - A holistic structure for managing Bengaluru is guided by constitutional principles
# - Recommendations provide for the Greater Bengaluru Authority (GBA) as a Local Planning Authority (LPA)
# - The suggested architecture for managing Bengaluru promotes Political Devolution
# - The suggested architecture for managing Bengaluru promotes Decentralised Accountability
# - The suggested architecture for managing Bengaluru supports co-existence of larger Metropolitan governance structures
# - The suggested architecture for managing Bengaluru supports protecting the devolved powers at the lower levels
# - Metropolitan governance structures aim to protect and reinforce brand Bengaluru
# - The suggested architecture for managing Bengaluru includes ‘Watch dog’ mechanisms
# - A Greater Bengaluru Finance Commission is for fair and equitable distribution of resources
# - A Greater Bengaluru Finance Commission is for problem resolution
# - A Greater Bengaluru Services Ombudsman allows citizens to make their case for better civic services
# - A Municipalisation Committee is housed within the Greater Bengaluru Authority
# - The Committee suggested a 3 tier governance framework for Bengaluru
# - A 3 tier governance framework for Bengaluru includes Ward, Municipal Corporation, Greater Bengaluru Authority (GBA)
# - The current Bengaluru Metropolitan Area has a footprint of 1,307 sq kms
# - Bengaluru today has an inner core (within Outer Ring Road)
# - Bengaluru today has an outer periphery
# - Proposed Greater Bengaluru Finance Commission should set out a basis for financial devolution to the ward
# - Bengaluru's population is projected to be over 20 million by 2040
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - Nearly half of Bengaluru's population lives in wards in the outer areas
# - Bengaluru has a population of 10 million
# - Bengaluru has an area of 709.5 sq kms
# - No city with Bengaluru's population and area operates as a single Corporation entity
# - Bengaluru's growth has been rapid since 2001
# - Bengaluru's growth is projected to continue until 2040
# - Bengaluru's growth has occurred beyond the Outer Ring Road
# - 5 Corporation solution balanced various areas of Bengaluru
# - 5 Corporation solution kept intact essential character of Bengaluru
# - 5 Corporation model epitomises a Bengaluru aligned to its historical roots
# - Kempegowda is Bengaluru’s founder
# - Kempegowda II moved base to Bengaluru
# - 4 pillars represent boundaries of Bengaluru
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - Brand Bengaluru is shaped by its people
# - Brand Bengaluru is shaped by its ethos
# - Brand Bengaluru is shaped by its culture
# - Brand Bengaluru is shaped by its vibrancy
# - Brand Bengaluru is shaped by its promise
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - Greater Bengaluru Authority is a recommendation for Bengaluru
# - Greater Bengaluru Authority will help build brand Bengaluru
# - Greater Bengaluru Authority will help sustain brand Bengaluru
# - Greater Bengaluru Authority will help nurture brand Bengaluru
# - directly elected Mayor will act as precursor to directly elected Metropolitan Mayor of the Greater Bengaluru Authority
# - Tier 2 and Tier 3 arrangements will work only if there is a Greater Bengaluru layer (Tier 1)
# - Greater Bengaluru layer (Tier 1) integrates all civic activities
# - Greater Bengaluru layer (Tier 1) takes responsibility for planning and administration of Bengaluru metropolitan activities
# - Lack of attention and future planning for the extended region is a cause of Bengaluru’s current woes
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Greater Bengaluru Authority (GBA) is the apex body
# - Greater Bengaluru Authority (GBA) is strongly advocated on multiple counts
# - Nearly all stakeholders consulted have voiced concerns about protecting the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about nurturing the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about growing the Bengaluru brand
# - Greater Bengaluru Authority (GBA) will ensure all activities in the metropolitan area are in sync with building brand Bengaluru
# - Lack of inter-agency coordination due to organisation silos is a complaint of Bengaluru citizens
# - Economic Development Agency has scope for Bengaluru to be at the forefront on city economy innovation
# - Footprint of the GBA is ideally Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
# - proposed Greater Bengaluru Authority will be headed initially by Chief Minister
# - Greater Bengaluru Authority should go in for a directly elected ‘Metropolitan Mayor’
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - GBA includes 5 Bengaluru City MLAs
# - Bengaluru City MLAs are members of relevant Municipal Corporation
# - Greater Bengaluru Finance Commission is for fair and equitable distribution
# - Bengaluru needs a planning body
# - A planning body looks out for development activities on Bengaluru's outskirts
# - Several urban local bodies are almost contiguous to Bengaluru
# - Bengaluru is one city
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - BBMP (Estate Management) Rules 2024 provide for proper management of 6,818 properties
# - State Government grant was expected to be Rs.3,475.97 crores during FY 2024-25
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - State government identified need for comprehensive solid waste management
# - Project for Integrated Solid Waste Management has been approved by state government
# - Proposal for land acquisition has been submitted to state government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - Karnataka State was a pioneer in initiating devolution of powers under Panchayat Raj
# - State has overriding influence over Bengaluru
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - No one seems responsible for the state of the city
# - Quarterly meetings give MLAs a handle on the state of civic affairs of their wards
# - The State has had a major role in the city
# - State level has no legal arrangement for managing a Metropolitan city
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - Economic development is not real-estate development
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - Procurement of laboratory equipment cost 10000000
# - Repairs and renovations work targets development of 10 new playgrounds
# - 306 students achieved highest ranks in 10th Std, 2nd P.U. (12th) and final degree
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - Waste collection and processing area is 50 to 100 acres
# - Rs. 100 crores will be spent on land acquisition (once approved)
# - Establishment of 22 dry waste collection units increased daily dry waste collection capacity by 100 tons
# - 100 women friendly toilets are being planned under 4 packages
# - More than 10,000 applications processed through Sakala
# - More than 10,000 applications processed through Sahaya
# - Establishment of three Hi-Tech Nurseries costs Rs.10 crores
# - Rs.10 crores is expected to be spent on RMP road widening in 2024-25
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Black topping has a cost of Rs.100 crores
# - Rs.100 crores will be spent from earmarked Rs.300 crores
# - Rs.10 crores is expected to be spent in FY 2024-25 for flood mitigation and disaster management
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - 2007 amalgamation involved 110 villages
# - current BBMP area has a population of around 10 million
# - Elected category members (Ward Committee) number 10
# - 10% vote share for a candidate results in a seat in Ward Committee (Elected category)
# - Nominated category members (Ward Committee) number 10
# - Bengaluru has a population of 10 million
# - 5 Commissioners and 10 Zonal Commissioners would oversee administration in their designated areas
# - 5 Commissioners and 10 Zonal Commissioners would be more effective than current set up
# - MC 1 has Population decadal growth % 103
# - Current system of dumping municipal solid waste involves dumping waste from a city of 10 million
# - Villages outside BBMP have a population of 500-1000
# - growth corridors have area of 1710 sq kms
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Works for development of 14 New Parks are under progress
# - Grant of Rs.49 crores given for rejuvenation of 14 lakes
# - Grant of Rs.49 crores given for development of 14 lakes
# - Works in 14 lakes are under progress
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - 2014 Population is set out against each of the 5 Corporations
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Police stations 14
# - MC 5 has Road length (kms)/Sq. Kms 14.7
# - Provision of furniture to 40 schools cost 15099700
# - An additional 150 km of roads are being developed with white-topping from the year 2023-24
# - Rs. 15 crores were allocated under 15th Finance Commission Grants
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Secondary scientific waste transfer centers have a capacity of 150 to 200 metric tons per day
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - 15,600 pourakarmikas are employed under direct payment system
# - Three Hi-Tech Nurseries being established under 15th Finance Commission grants
# - Grant of Rs.49 crores given under 15th Finance Commission grants
# - BBMP has provided sarees to 15,150 Pourakarmikas
# - BBMP has provided aprons to 15,150 Pourakarmikas
# - BBMP has provided sweaters to 15,150 Pourakarmikas
# - BBMP has provided track pants to 15,150 Pourakarmikas
# - Rs.150 crores are expected to be spent in 2024-25 (from re-appropriation)
# - Shri V. Ravichandar worked closely on urban issues for 15 years
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Population within Outer Ring Road (ORR) in BBMP (2015) was approximately equal to population outside Outer Ring Road (ORR) in BBMP (2015)
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Area (sq km) 150.5
# - MC 2 has Population decadal growth % 15
# - MC 3 has Area (sq km) 157.2
# - MC 5 has Population density (2011) 7,515 per sq.km
# - GBA includes 15 representatives from the Municipal Corporation level
# - 2007 amalgamation involved Bangalore Mahanagar Palike (BMP)
# - 2007 amalgamation involved 7 City Municipal Councils (CMC)
# - 2007 amalgamation involved 1 Town Municipal Council (TMC)
# - 2007 amalgamation involved 110 villages
# - 2007 amalgamation did not yield expected gains
# - Property tax rates have not been revised since 2007
# - The existing 198 wards were formed during the amalgamation of 2007
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Earlier villages were outside the limits of the pre 2007 BMP
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements

# %% [markdown]
# ## Execute queries and analyze results
#
# ### Subtask:
# Run test queries to see how the integrated system performs and analyze the retrieved information.

# %% [markdown]
# **Reasoning**:
# Define a list of test queries and iterate through them, calling the augment_with_triplets function for each and printing the results as instructed.

# %%
# 1. Define a list of diverse test queries
test_queries = [
    "What is the Bruhat Bengaluru Mahanagara Palike?",
    "Tell me about Zonal Commissioners.",
    "What is the BBMP Act - 2020 about?",
    "Explain the structure of BBMP.",
    "What is the significance of the pre 2007 BMP?"
]

# 2. Iterate through the list of test queries and process each one
for i, query in enumerate(test_queries):
    print(f"Processing Query {i+1}: {query}")
    print("--- Augmented Results ---")

    # Call the augment_with_triplets function
    augmented_chunks = augment_with_triplets(query, results, df_triplets)

    # Print the augmented text chunks
    if augmented_chunks:
        for j, chunk in enumerate(augmented_chunks):
            print(f"Augmented Chunk {j+1}:")
            print(chunk)
            print("\n")
    else:
        print("No augmented chunks returned.")

    print("--- End of Query ---")
    print("\n")

# 3. Manual analysis will be performed after the output is generated.
# 4. A summary of observations will be formulated manually after the output is generated.
# Out:
# Streaming output truncated to the last 5000 lines.
# - A 3 tier governance framework for Bengaluru includes Ward, Municipal Corporation, Greater Bengaluru Authority (GBA)
# - The current Bengaluru Metropolitan Area has a footprint of 1,307 sq kms
# - Bengaluru today has an inner core (within Outer Ring Road)
# - Bengaluru today has an outer periphery
# - Proposed Greater Bengaluru Finance Commission should set out a basis for financial devolution to the ward
# - Bengaluru's population is projected to be over 20 million by 2040
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - Nearly half of Bengaluru's population lives in wards in the outer areas
# - Bengaluru has a population of 10 million
# - Bengaluru has an area of 709.5 sq kms
# - No city with Bengaluru's population and area operates as a single Corporation entity
# - Bengaluru's growth has been rapid since 2001
# - Bengaluru's growth is projected to continue until 2040
# - Bengaluru's growth has occurred beyond the Outer Ring Road
# - 5 Corporation solution balanced various areas of Bengaluru
# - 5 Corporation solution kept intact essential character of Bengaluru
# - 5 Corporation model epitomises a Bengaluru aligned to its historical roots
# - Kempegowda is Bengaluru’s founder
# - Kempegowda II moved base to Bengaluru
# - 4 pillars represent boundaries of Bengaluru
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - Brand Bengaluru is shaped by its people
# - Brand Bengaluru is shaped by its ethos
# - Brand Bengaluru is shaped by its culture
# - Brand Bengaluru is shaped by its vibrancy
# - Brand Bengaluru is shaped by its promise
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - Greater Bengaluru Authority is a recommendation for Bengaluru
# - Greater Bengaluru Authority will help build brand Bengaluru
# - Greater Bengaluru Authority will help sustain brand Bengaluru
# - Greater Bengaluru Authority will help nurture brand Bengaluru
# - directly elected Mayor will act as precursor to directly elected Metropolitan Mayor of the Greater Bengaluru Authority
# - Tier 2 and Tier 3 arrangements will work only if there is a Greater Bengaluru layer (Tier 1)
# - Greater Bengaluru layer (Tier 1) integrates all civic activities
# - Greater Bengaluru layer (Tier 1) takes responsibility for planning and administration of Bengaluru metropolitan activities
# - Lack of attention and future planning for the extended region is a cause of Bengaluru’s current woes
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Greater Bengaluru Authority (GBA) is the apex body
# - Greater Bengaluru Authority (GBA) is strongly advocated on multiple counts
# - Nearly all stakeholders consulted have voiced concerns about protecting the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about nurturing the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about growing the Bengaluru brand
# - Greater Bengaluru Authority (GBA) will ensure all activities in the metropolitan area are in sync with building brand Bengaluru
# - Lack of inter-agency coordination due to organisation silos is a complaint of Bengaluru citizens
# - Economic Development Agency has scope for Bengaluru to be at the forefront on city economy innovation
# - Footprint of the GBA is ideally Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
# - proposed Greater Bengaluru Authority will be headed initially by Chief Minister
# - Greater Bengaluru Authority should go in for a directly elected ‘Metropolitan Mayor’
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - GBA includes 5 Bengaluru City MLAs
# - Bengaluru City MLAs are members of relevant Municipal Corporation
# - Greater Bengaluru Finance Commission is for fair and equitable distribution
# - Bengaluru needs a planning body
# - A planning body looks out for development activities on Bengaluru's outskirts
# - Several urban local bodies are almost contiguous to Bengaluru
# - Bengaluru is one city
# - Permanent invitees include DULT
# - Revenue collected from Premium FAR charges will be utilized for infrastructure development
# - A one-month pilot project was implemented to identify issues in civic infrastructure
# - AI Based video feed analysis is for identification and analysis of civic infrastructure issues
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Unplanned growth led to huge infrastructure deficiencies
# - Greater Bangalore Authority/Council is responsible for infrastructure development
# - Expert Committee's mandate focused on Access to quality infrastructure and services
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - Wards with historical infrastructure deficiencies would need additional intervention through proposed GBA
# - inability to reorganise ward wise is due to operation logistics, infrastructure, and costs
# - One key objective of amalgamation was to provide infrastructure in outlying areas
# - Infrastructure provision in outlying areas has not been achieved as an objective of amalgamation
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - infrastructure availability was estimated for these 5 Corporation areas
# - infrastructure availability is detailed in Chapter 3
# - infrastructure availability is detailed in Appendix IV
# - estimated infrastructure availability can be used to decide on investment decisions
# - investment decisions aim to raise infrastructure quotient in under developed wards
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Civic requirements executed on a larger scale include major road infrastructure
# - Planning functions will encompass close inter-linkages between land use plans, mobility, infrastructure, economic development plans
# - GBA will manage Mega Infrastructure projects
# - Mega Infrastructure projects span the city
# - Mega Infrastructure projects include major arterial roads
# - Mega Infrastructure projects include storm water drains
# - Mega Infrastructure projects include flyovers
# - Mega Infrastructure projects include bus rapid transit systems
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - The 250 meter High Sky Deck aims to promote tourism
# - 225 wards formed in accordance with BBMP Act - 2020
# - A draft prepared for amendment of BBMP Cadre and Recruitment Rules
# - The draft (BBMP Cadre and Recruitment Rules amendment) will be submitted to the Government
# - BBMP commenced recruitment process of Direct Payment System Pourakarmikas
# - BBMP is taking action to review and implement recommendations of Administrative Reforms Commission reports
# - Corpus fund facilitates welfare of the retired employees of BBMP
# - The proposal (to establish Pensioners’ Arogya Kalyana Nidhi Scheme) received approval from Hon’ble Administrator of BBMP
# - An Information Technology (IT) Cell has been operationalized by BBMP
# - A Contactless and Faceless online e-khata system adopted by BBMP
# - BBMP achieved highest property tax collection in the country in FY 2023-24
# - BBMP recovered Rs. 1,277 crores arrears of property tax
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - BBMP (Estate Management) Rules 2024 provide for proper management of 6,818 properties
# - Rs.2,817.96 crores of Government grants have been received by BBMP till February 2025
# - BBMP's IT section implemented various softwares
# - The e-Aasthi system has been developed by BBMP's IT section
# - GIS mapping of properties in BBMP is incorporated into e-Aasthi system
# - The draft e-khata is available on BBMP e-Aasthi website
# - Court Case Management System (CCMS) is implemented in BBMP
# - Advertisement Management Software has been developed by Information Technology Section (BBMP)
# - Fix Pothole Software operates in BBMP areas
# - AI Based video feed analysis operates in BBMP
# - 250 dash cameras shall be installed on BBMP vehicles
# - Information from Artificial Intelligence (AI) software will be integrated with BBMP’s existing Sahaaya Software
# - BBMP online service is being integrated with EODB
# - BBMP’s various softwares are being integrated under EODB
# - Karnataka Government has mandated that BBMP services be provided online
# - 23,341 students are studying under BBMP’s Education Department
# - BBMP’s Education Department operates 93 Nursery Schools
# - BBMP’s Education Department operates 16 Primary Schools
# - BBMP’s Education Department operates 34 High Schools
# - BBMP’s Education Department operates 19 P.U. Colleges
# - BBMP’s Education Department operates 4 Graduate Colleges
# - BBMP’s Education Department operates 2 Post Graduate Colleges
# - School Development and Monitoring Committee (SDMC) is functional in all BBMP schools
# - College Development Committees (CDC) are functional in all BBMP colleges
# - All BBMP school and college students were provided with two sets of uniform
# - All BBMP school and college students were provided with shoes and socks
# - All BBMP school and college students were provided with notebooks
# - All BBMP school and college students were provided with textbooks
# - All BBMP school and college students were provided with sweaters
# - All BBMP school and college students were provided with school bags
# - All BBMP school and college students were provided with a Mid-day meal
# - Age group-wise library books were provided to BBMP schools/colleges
# - Sports equipment were provided to BBMP schools/colleges
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - Pratham Education Foundation supports BBMP schools
# - Systemic change is achieved by strengthening monitoring capacities of BBMP monitoring cadre
# - The learning improvement program has been implemented in 16 primary schools under BBMP
# - The learning improvement program has been implemented in 93 nursery schools under BBMP
# - BBMP education department is procuring laboratory equipment
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - BBMP aimed to provide a better experience to BBMP school and college students
# - BBMP took BBMP school and college students on educational excursions to various historical, cultural and eco spots of Karnataka
# - BBMP has started biometric face identification and geo-fenced attendance systems
# - BBMP became the first corporation to launch the combined vaccination for street dogs for 5 diseases
# - BBMP became the first corporation to start feeding its stray dogs on pilot basis
# - Approximately 200 km of roads within the jurisdiction of the BBMP have been white-topped
# - BBMP is currently maintaining about 1,280 parks
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - Hasiru Mitra has been developed by BBMP Horticulture wing
# - BBMP Horticulture wing developed Hasiru Mitra in coordination with IT team
# - Agencies appointed by BBMP maintain parks
# - BBMP appoints agencies through tender process
# - CIPC enables stakeholders to assist BBMP
# - BBMP associated with Association for physically challenged
# - BBMP provided physiotherapy to more than 600 children
# - OPD services at BBMP’s Namma Clinics increased to average 40 out-patients per day
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - BBMP Forest wing manages trees through 30 tree canopy management teams
# - Three Hi-Tech Nurseries being established under BBMP grants
# - BBMP has in its jurisdiction 183 live lakes
# - BBMP's role is to develop lakes
# - BBMP's role is to rejuvenate lakes
# - BBMP's role is to maintain lakes
# - Kere Mitra App can be used by BBMP officials
# - BBMP officials use Kere Mitra App to monitor agencies in lake maintenance
# - BBMP officials use Kere Mitra App to supervise agencies in lake maintenance
# - BBMP lakes division protects lakes and its premises
# - BBMP lakes division coordinates with Revenue Department
# - BBMP lakes division coordinates with Survey wing
# - BBMP lakes division coordinates with BBMP zonal engineers
# - BBMP lakes division aims to identify boundaries
# - BBMP lakes division aims to demarcate boundaries
# - BBMP lakes division aims to remove encroachments
# - Boundary of 27 lakes demarcated with BBMP grant of Rs. 40 crores
# - BBMP’s CAC has taken a big step towards Climate Budgeting
# - BBMP’s CAC has taken a big step towards Monitoring Evaluation and Reporting (MER) of sector-wise actions
# - BBMP has implemented the Pension Scheme for retired DPS pourakarmikas
# - BBMP has provided sarees to 15,150 Pourakarmikas
# - BBMP has provided aprons to 15,150 Pourakarmikas
# - BBMP has provided sweaters to 15,150 Pourakarmikas
# - BBMP has provided track pants to 15,150 Pourakarmikas
# - BBMP has deployed 5 high pressure Power Jetting Road Washing Machines
# - New Advertisement Bye-law 2024 was proposed by BBMP
# - New Advertisement Bye-law facilitates BBMP to earn more revenue
# - Public Relations Department publicizes the importance of each service and project implemented by BBMP
# - BBMP properties notified in Karnataka Gazette have been uploaded to BBMP website (www.bbmp.gov.in)
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - lease amount for BBMP properties will be fixed based on guidance value
# - survey of existing 6819 BBMP properties has begun under Section 136 (4) of the Bruhat Bengaluru Mahanagara Palike Act - 2020
# - survey of existing 6819 BBMP properties uses ROVERS
# - 60% of BBMP properties of Raja Rajeshwari Nagar zone have been surveyed
# - separate Survey Wing (209 personnel) has been approved for surveying 20 lakhs private properties and 6819 BBMP properties
# - Details of the Committee's work are set out in website www.bbmprestructuring.org
# - The Committee understood current status of the Municipal Corporation (BBMP)
# - Current status of Municipal Corporation (BBMP) includes organizational structure
# - Current status of Municipal Corporation (BBMP) includes finances
# - Current status of Municipal Corporation (BBMP) includes human resources
# - Current status of Municipal Corporation (BBMP) includes delegation of powers
# - Current status of Municipal Corporation (BBMP) includes role responsibilities of Council
# - Current status of Municipal Corporation (BBMP) includes zonal offices
# - Current status of Municipal Corporation (BBMP) includes wards
# - B.S. Patil has invaluable experience and knowledge on BBMP
# - B.S. Patil served as Commissioner on BBMP on two occasions
# - Shri V. Ravichandar contributed to innovative tax reforms within BBMP
# - The Committee submitted its report on ‘BBMP Restructuring’
# - The report on ‘BBMP Restructuring’ was submitted to Govt. of Karnataka
# - B.S. Patil provided leadership for the BBMP Restructuring exercise
# - B.S. Patil provided wise counsel for the BBMP Restructuring exercise
# - B.S. Patil provided sage advice for the BBMP Restructuring exercise
# - The Expert Committee was constituted to suggest division of BBMP into smaller municipal areas
# - Villages added to BBMP lack basic amenities
# - BBMP set up lacked appropriate governance
# - BBMP set up lacked administration
# - BBMP set up lacked people capacity
# - Current setup includes BBMP
# - www.bbmprestructuring.org is a web site
# - www.bbmprestructuring.org was set up as two-way communication platform between Citizens and the Expert Committee
# - BBMP is plagued by multiple deficits
# - BBMP has Ineffective Governance and Administration
# - Standing Committees in BBMP are omnibus and ineffective
# - Standing Committees in BBMP include around 132 Councillors across 12 Committees
# - BBMP has a trust deficit
# - Inflated contract values are considered the norm at BBMP
# - Financial indiscipline is the norm at BBMP
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - Property tax payers (BBMP) are less than 50% of estimated
# - Revenue realisations (BBMP) are low
# - BBMP has poor Human resources
# - C&R (Cadre & Recruitment) Rules, 1971 govern BBMP
# - In-house employees (BBMP) lack urban expertise
# - In-house employees (BBMP) have no training
# - External resources at senior levels (BBMP) have limited capabilities
# - External resources at senior levels (BBMP) have no long term commitment to BBMP
# - External resources at senior levels (BBMP) are detrimental to developing a healthy internal culture
# - Specific job-oriented training (BBMP) is negligible
# - Induction program (BBMP) is non-existent
# - BBMP has a staff shortage of about 35% vis-à-vis sanctioned capacity
# - BBMP lacks Transparency
# - BBMP's operations and finances are shrouded in secrecy
# - Visibility on where money is spent (BBMP) is non-existent
# - MIS system (BBMP) is not in place
# - Senior officers (BBMP) are severely handicapped in taking decisions
# - Appetite for proactive disclosure (BBMP) is non-existent
# - Central Accounts Office of BBMP was not part of computerised accounting system at Zonal level
# - Financial audit (BBMP) has not occurred for over four years
# - Internal records (BBMP) are poor
# - BBMP suffers from Financial Mismanagement
# - BBMP has own revenue sources of around Rs. 1800 crores annually (including arrears)
# - BBMP had pending bills as of Apr 1, 2015 of Rs. 2,300 crores
# - BBMP had a loan of around Rs. 2,200 crores
# - BBMP had Spill over works of Rs. 3,000 crores
# - BBMP's financial situation is indicative of serious financial stress
# - Approach to haphazard urban developments on the outskirts of the BBMP area is reactive
# - The Expert Committee on BBMP Restructuring focussed on finding systemic remedies
# - The existing 198 wards are in the BBMP area of 709.5 sq kms
# - current BBMP area has a population of around 10 million
# - Committee suggests about 400 wards for current BBMP area
# - citizens expect BBMP and civic service providers to align activities at ward level
# - Current single BBMP model is unsustainable
# - Current single BBMP model is not effective currently
# - A single BBMP Commissioner finds it near impossible to effectively administer a wide populace over a large geographic area
# - BBMP currently has 8 Zonal units
# - Population within Outer Ring Road (ORR) in BBMP (2015) was approximately equal to population outside Outer Ring Road (ORR) in BBMP (2015)
# - Population in outer areas (of BBMP) is projected to increase relative to population within Outer Ring Road (ORR)
# - Current single BBMP model has 261 members
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - recommendation to make BBMP into multiple units is driven by desire to make the city more manageable
# - recommendation to make BBMP into multiple units is driven by desire to make the city more liveable
# - Current system of dumping municipal solid waste involves dumping waste in villages outside BBMP
# - Villages outside BBMP have a population of 500-1000
# - BBMP has area of 709.5 sq kms
# - BMA footprint consists of BBMP + BDA
# - The restructuring exercise should include planned municipalisation of portions of the GBA that are outside BBMP limits
# - Portions of the GBA outside BBMP limits have seen a significant rise in home construction
# - BBMP is the result of the municipalisation and absorption of earlier villages
# - BDA is a silo 'parastatal'
# - A Municipalisation Committee is housed in the BDA
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - BMA footprint consists of BBMP + BDA
# - Zilla Parishad representatives are from BDA area
# - Municipalisation Committee is for orderly transition of rural to urban areas in BDA
# - BDA can report to GBA
# - MPC has been notified for the BDA area
# - About 25 villages are in the BDA area
# - About 25 villages in the BDA area exhibit urban characteristics
# - The BDA area is full of urban fragments
#
#
#
# Augmented Chunk 5:
# Economic Profile
#
# 0 Highest contributor to the State economy with 33.3% contribution to
# GDDP (INR 99,325 Crore) (2012-2013)
#
# 6 Per capita annual income in the district is INR 2,02,340 for the year 2012-13
#
#
#
#
# 6 Country’s fourth largest fast moving consumer goods (FMCG) market
#
#
#
#
# Bengaluru Urban District’s Contribution to GSDP of Karnat:
#
# (2012-13)
# Description INR Contribution (%)
# Crore
# Total District GDP 99,325 33.3
# Agriculture and Allied 967 2.3
#
# (Agriculture, Animal
# Husbandry, Forestry, Fishing)
#
# Industry 30,028 36
# (Manufacturing,
# Construction, Mining)
#
# Services 68,330 39.5
# (Real estate, Hotels and
# restaurants, banking, and
# legal services)
#
#
#
#
#
# Bengaluru Urban GDP Trend (In INR Crore)
#
#
#
# 96,232 99,325
#
# 84,072 84,336 86,831
# | . |
#
# 2007-08 2008-09 2009-10 2010-11 2011-12 2012-13
#
#
#
# Source: State and District Domestic Product of Karnataka 14-15 m Primary MSecondary MTertiary © GDDP
#
# IK 2016 | BENGALURU URBAN gO
#
# Related Information from Knowledge Graph:
# - No one seems responsible for the state of the city
# - Quarterly meetings give MLAs a handle on the state of civic affairs of their wards
# - The State has had a major role in the city
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
# - Comprehensive solid waste management is part of Brand Bengaluru concept
# - Bruhat Bengaluru Mahanagara Palike has a newly formed health & sanitation wing
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - Pourakarmikas contribute to sanitation efforts of Bengaluru city
# - Government approved implementation of Arogya Bengaluru Scheme
# - Arogya Bengaluru Scheme is under Brand Bengaluru campaign
# - Arogya Bengaluru Scheme will lead to up-gradation of 19 hospitals
# - Arogya Bengaluru Scheme will boost diagnostics facilities
# - Arogya Bengaluru Scheme will provide 60 plus tests free of cost
# - Arogya Bengaluru Scheme will provide dental services at 26 new points
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - 1,13,000 saplings planted in Bengaluru
# - Five tree parks being developed under "Brand Bengaluru -Green Bengaluru" initiative
# - Lakes of Bengaluru have major historical value
# - Lakes of Bengaluru have major cultural value
# - Lakes of Bengaluru enhance livability of the city
# - Rs.35 crores allocated under “Brand Bengaluru -Green Bengaluru” grant
# - Bengaluru Climate Action Plan (BCAP) is associated with Climate Action Cell (CAC)
# - Bengaluru Climate Action Cell (CAC) commenced operations in February 2024
# - Bengaluru Climate Action Cell (CAC) marks a pivotal moment in city's commitment to addressing climate change
# - Bengaluru Climate Action Cell (CAC) has primary objective to facilitate implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action Cell (CAC) has primary objective to spearhead implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# - Bengaluru Climate Action and Resilience Plan (BCAP) is implemented within jurisdictional limits of Bruhat Bengaluru Mahanagara Palike
# - Fellowship program aims to bolster implementation of Bengaluru's climate action initiatives
# - The Blue-Green Awards have been instituted to recognize individuals making a significant impact in advancing Bengaluru's climate action aspirations
# - The Blue-Green Awards have been instituted to recognize organizations making a significant impact in advancing Bengaluru's climate action aspirations
# - CAC demonstrated a comprehensive approach to driving Bengaluru's climate action
# - CAC demonstrated a collaborative approach to driving Bengaluru's climate action
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - survey of existing 6819 BBMP properties has begun under Section 136 (4) of the Bruhat Bengaluru Mahanagara Palike Act - 2020
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - "Sancharyukta Bengaluru" works have an approved cost of Rs.200 crores
# - tenders have been invited for "Sancharyukta Bengaluru" works worth Rs.47 crores
# - an estimate has been prepared for remaining "Sancharyukta Bengaluru" works worth Rs.53 crores
# - "Sancharyukta Bengaluru" road works will be executed after acquisition of land from the Defense Department
# - Rs.50 crores have been provided for widening of RMP roads under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.50 crores have been provided for construction of RMP road under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Rs.200 crores have been allocated for Bengaluru Urban Tunnel Project
# - Bengaluru Urban Tunnel Project is part of Bengaluru Urban Integrated Mobility Project
# - Rs.50 crores (for Bengaluru Urban Tunnel Project) is expected to be utilized in the project
# - tenders have been invited for development of Padarayanapura road under Sugama Sanchara Bengaluru
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - BRUHAT BENGALURU MAHANAGARA PALIKE has a PERFORMANCE REPORT OF 2024-25
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Vibrant Bengaluru theme is under Brand Bengaluru Campaign
# - Vibrant Bengaluru theme is for the project Decorative Electrification Project
# - Chapter 2 is titled Bengaluru: Karnataka's prime urban centre
# - Bengaluru was known as ‘Garden City’
# - Bengaluru had abundance of greenery
# - Young minds made Bengaluru a software capital of the world
# - The metropolitan city (Bengaluru) registered highest growth rate of 44.6%
# - Bengaluru’s urban management has come under severe criticism
# - The report establishes a need for urgent structural changes in Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - Bengaluru Metropolitan Area (BMA) is projected to have a population of 20 million by 2040
# - Greater Bangalore Authority ensures Bengaluru remains as one city governance
# - Expert Committee's mandate focused on improving quality of life for all citizens in Bengaluru
# - State has overriding influence over Bengaluru
# - Bengaluru has a weak, one-year 'titular' mayor system
# - The garbage problem in Bengaluru has been festering for over three years
# - The garbage problem in Bengaluru is without a positive resolution
# - Existing infirmities are holding back Bengaluru
# - Bengaluru is prevented from realising its potential as the best city in India
# - Bengaluru is prevented from realising its potential as one of the truly liveable global cities in the world
# - The city (Bengaluru) needs to be an engine of economic growth
# - The city (Bengaluru) needs to be creating livelihoods
# - The city (Bengaluru) needs to be attracting investments
# - Realising the holistic vision for Bengaluru will call for political will
# - Realising the holistic vision for Bengaluru will call for administrative support
# - The Committee recommends a holistic structure for managing Bengaluru
# - A holistic structure for managing Bengaluru is guided by constitutional principles
# - Recommendations provide for the Greater Bengaluru Authority (GBA) as a Local Planning Authority (LPA)
# - The suggested architecture for managing Bengaluru promotes Political Devolution
# - The suggested architecture for managing Bengaluru promotes Decentralised Accountability
# - The suggested architecture for managing Bengaluru supports co-existence of larger Metropolitan governance structures
# - The suggested architecture for managing Bengaluru supports protecting the devolved powers at the lower levels
# - Metropolitan governance structures aim to protect and reinforce brand Bengaluru
# - The suggested architecture for managing Bengaluru includes ‘Watch dog’ mechanisms
# - A Greater Bengaluru Finance Commission is for fair and equitable distribution of resources
# - A Greater Bengaluru Finance Commission is for problem resolution
# - A Greater Bengaluru Services Ombudsman allows citizens to make their case for better civic services
# - A Municipalisation Committee is housed within the Greater Bengaluru Authority
# - The Committee suggested a 3 tier governance framework for Bengaluru
# - A 3 tier governance framework for Bengaluru includes Ward, Municipal Corporation, Greater Bengaluru Authority (GBA)
# - The current Bengaluru Metropolitan Area has a footprint of 1,307 sq kms
# - Bengaluru today has an inner core (within Outer Ring Road)
# - Bengaluru today has an outer periphery
# - Proposed Greater Bengaluru Finance Commission should set out a basis for financial devolution to the ward
# - Bengaluru's population is projected to be over 20 million by 2040
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - Nearly half of Bengaluru's population lives in wards in the outer areas
# - Bengaluru has a population of 10 million
# - Bengaluru has an area of 709.5 sq kms
# - No city with Bengaluru's population and area operates as a single Corporation entity
# - Bengaluru's growth has been rapid since 2001
# - Bengaluru's growth is projected to continue until 2040
# - Bengaluru's growth has occurred beyond the Outer Ring Road
# - 5 Corporation solution balanced various areas of Bengaluru
# - 5 Corporation solution kept intact essential character of Bengaluru
# - 5 Corporation model epitomises a Bengaluru aligned to its historical roots
# - Kempegowda is Bengaluru’s founder
# - Kempegowda II moved base to Bengaluru
# - 4 pillars represent boundaries of Bengaluru
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - Brand Bengaluru is shaped by its people
# - Brand Bengaluru is shaped by its ethos
# - Brand Bengaluru is shaped by its culture
# - Brand Bengaluru is shaped by its vibrancy
# - Brand Bengaluru is shaped by its promise
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - Greater Bengaluru Authority is a recommendation for Bengaluru
# - Greater Bengaluru Authority will help build brand Bengaluru
# - Greater Bengaluru Authority will help sustain brand Bengaluru
# - Greater Bengaluru Authority will help nurture brand Bengaluru
# - directly elected Mayor will act as precursor to directly elected Metropolitan Mayor of the Greater Bengaluru Authority
# - Tier 2 and Tier 3 arrangements will work only if there is a Greater Bengaluru layer (Tier 1)
# - Greater Bengaluru layer (Tier 1) integrates all civic activities
# - Greater Bengaluru layer (Tier 1) takes responsibility for planning and administration of Bengaluru metropolitan activities
# - Lack of attention and future planning for the extended region is a cause of Bengaluru’s current woes
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Greater Bengaluru Authority (GBA) is the apex body
# - Greater Bengaluru Authority (GBA) is strongly advocated on multiple counts
# - Nearly all stakeholders consulted have voiced concerns about protecting the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about nurturing the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about growing the Bengaluru brand
# - Greater Bengaluru Authority (GBA) will ensure all activities in the metropolitan area are in sync with building brand Bengaluru
# - Lack of inter-agency coordination due to organisation silos is a complaint of Bengaluru citizens
# - Economic Development Agency has scope for Bengaluru to be at the forefront on city economy innovation
# - Footprint of the GBA is ideally Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
# - proposed Greater Bengaluru Authority will be headed initially by Chief Minister
# - Greater Bengaluru Authority should go in for a directly elected ‘Metropolitan Mayor’
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - GBA includes 5 Bengaluru City MLAs
# - Bengaluru City MLAs are members of relevant Municipal Corporation
# - Greater Bengaluru Finance Commission is for fair and equitable distribution
# - Bengaluru needs a planning body
# - A planning body looks out for development activities on Bengaluru's outskirts
# - Several urban local bodies are almost contiguous to Bengaluru
# - Bengaluru is one city
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - BBMP (Estate Management) Rules 2024 provide for proper management of 6,818 properties
# - State Government grant was expected to be Rs.3,475.97 crores during FY 2024-25
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - State government identified need for comprehensive solid waste management
# - Project for Integrated Solid Waste Management has been approved by state government
# - Proposal for land acquisition has been submitted to state government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - Karnataka State was a pioneer in initiating devolution of powers under Panchayat Raj
# - State has overriding influence over Bengaluru
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - No one seems responsible for the state of the city
# - Quarterly meetings give MLAs a handle on the state of civic affairs of their wards
# - The State has had a major role in the city
# - State level has no legal arrangement for managing a Metropolitan city
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - Economic development is not real-estate development
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - Procurement of laboratory equipment cost 10000000
# - Repairs and renovations work targets development of 10 new playgrounds
# - 306 students achieved highest ranks in 10th Std, 2nd P.U. (12th) and final degree
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - Waste collection and processing area is 50 to 100 acres
# - Rs. 100 crores will be spent on land acquisition (once approved)
# - Establishment of 22 dry waste collection units increased daily dry waste collection capacity by 100 tons
# - 100 women friendly toilets are being planned under 4 packages
# - More than 10,000 applications processed through Sakala
# - More than 10,000 applications processed through Sahaya
# - Establishment of three Hi-Tech Nurseries costs Rs.10 crores
# - Rs.10 crores is expected to be spent on RMP road widening in 2024-25
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Black topping has a cost of Rs.100 crores
# - Rs.100 crores will be spent from earmarked Rs.300 crores
# - Rs.10 crores is expected to be spent in FY 2024-25 for flood mitigation and disaster management
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - 2007 amalgamation involved 110 villages
# - current BBMP area has a population of around 10 million
# - Elected category members (Ward Committee) number 10
# - 10% vote share for a candidate results in a seat in Ward Committee (Elected category)
# - Nominated category members (Ward Committee) number 10
# - Bengaluru has a population of 10 million
# - 5 Commissioners and 10 Zonal Commissioners would oversee administration in their designated areas
# - 5 Commissioners and 10 Zonal Commissioners would be more effective than current set up
# - MC 1 has Population decadal growth % 103
# - Current system of dumping municipal solid waste involves dumping waste from a city of 10 million
# - Villages outside BBMP have a population of 500-1000
# - growth corridors have area of 1710 sq kms
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Works for development of 14 New Parks are under progress
# - Grant of Rs.49 crores given for rejuvenation of 14 lakes
# - Grant of Rs.49 crores given for development of 14 lakes
# - Works in 14 lakes are under progress
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - 2014 Population is set out against each of the 5 Corporations
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Police stations 14
# - MC 5 has Road length (kms)/Sq. Kms 14.7
# - Provision of furniture to 40 schools cost 15099700
# - An additional 150 km of roads are being developed with white-topping from the year 2023-24
# - Rs. 15 crores were allocated under 15th Finance Commission Grants
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Secondary scientific waste transfer centers have a capacity of 150 to 200 metric tons per day
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - 15,600 pourakarmikas are employed under direct payment system
# - Three Hi-Tech Nurseries being established under 15th Finance Commission grants
# - Grant of Rs.49 crores given under 15th Finance Commission grants
# - BBMP has provided sarees to 15,150 Pourakarmikas
# - BBMP has provided aprons to 15,150 Pourakarmikas
# - BBMP has provided sweaters to 15,150 Pourakarmikas
# - BBMP has provided track pants to 15,150 Pourakarmikas
# - Rs.150 crores are expected to be spent in 2024-25 (from re-appropriation)
# - Shri V. Ravichandar worked closely on urban issues for 15 years
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Population within Outer Ring Road (ORR) in BBMP (2015) was approximately equal to population outside Outer Ring Road (ORR) in BBMP (2015)
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Area (sq km) 150.5
# - MC 2 has Population decadal growth % 15
# - MC 3 has Area (sq km) 157.2
# - MC 5 has Population density (2011) 7,515 per sq.km
# - GBA includes 15 representatives from the Municipal Corporation level
# - 2007 amalgamation involved Bangalore Mahanagar Palike (BMP)
# - 2007 amalgamation involved 7 City Municipal Councils (CMC)
# - 2007 amalgamation involved 1 Town Municipal Council (TMC)
# - 2007 amalgamation involved 110 villages
# - 2007 amalgamation did not yield expected gains
# - Property tax rates have not been revised since 2007
# - The existing 198 wards were formed during the amalgamation of 2007
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Earlier villages were outside the limits of the pre 2007 BMP
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
#
#
#
# --- End of Query ---
#
#
# Processing Query 4: Explain the structure of BBMP.
# --- Augmented Results ---
# Augmented Chunk 1:
# Investment Opportunities
#
# Name of the Project
#
#
#
# Construction of 221 public toilets in Bengaluru City
#
# Construction of Skywalks in Bengaluru City
#
# Redevelopment of Existing Markets in Bengaluru City
#
# Redevelopment of Commercial Complex at Indiranagar,
# Bengaluru
#
# Redevelopment of Commercial Complex at Vijayanagar,
# Bengaluru
#
# Development of Animation, Visual Effects, Gaming and
#
# 29 comics (AVGC Lab)
#
# fo)
#
# Development of Digital Media City
#
# i]
#
# Development of LEGO Theme Park at Bengaluru.
#
# i)
#
# Development of Disney Land Theme Park at Bengaluru
#
# Development of Cruise Dinner Project at Halasuru Lake,
# Bengaluru
#
# IN)
# aN
#
# i]
# wo
#
# Development of Snow Park in Bengaluru
#
# Development of Arts & Crafts Village in Bengaluru
#
# i}
# ron)
#
# i}
# NI
#
# Development of Bengaluru Eye
#
# IK 2016 | BENGALURU URBAN
#
# Sector
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Industrial
# Infrastructure -IT
# Parks
#
# Industrial
# Infrastructure -IT
# Parks
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# NA
#
# 335
#
# 40
#
# 26
#
# 782
#
# 62
#
# 100
#
# 40
#
# 43
#
# NA
#
# NA
#
# 56
#
# 130
#
# NA
#
# Agency
#
# BBMP
#
# BBMP
#
# BBMP
#
# BDA
#
# BDA
#
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
#
#
# Status
#
# Conceptualization
#
# Conceptualization
#
# Conceptualization
#
# Bidding Stage/
# DPR completed
#
# Conceptualization
#
# DPR under
# preparation
#
# DPR under
# preparation
#
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
#
# Related Information from Knowledge Graph:
# - Survey of 166 lakes is completed
# - actual boundaries need to be drawn after ward delimitation exercise is completed
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - 43 wards have a population of greater than 50,000
# - MC 3 has Population decadal growth % 43
# - Municipal Corporation functions derive from Article 243-W of the Twelfth Schedule of the Constitution
# - An Information Technology (IT) Cell has been operationalized by BBMP
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - Information Technology (IT) Cell is equipped with robust systems and mechanism
# - A separate helpline has been opened for assisting information /clarifications / complaints regarding e-khatha process
# - Advertisement Management Software has been developed by Information Technology Section (BBMP)
# - Information from Artificial Intelligence (AI) software will be integrated with BBMP’s existing Sahaaya Software
# - Information from Artificial Intelligence (AI) software will be integrated with Integrated Command and Control Center (ICCC)
# - CAC's official website serves as a central hub for information dissemination about CAC activities
# - CAC's official website serves as a central hub for information dissemination about CAC meetings
# - Research teams of experts compiled information
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
# - Comprehensive solid waste management is part of Brand Bengaluru concept
# - Bruhat Bengaluru Mahanagara Palike has a newly formed health & sanitation wing
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - Pourakarmikas contribute to sanitation efforts of Bengaluru city
# - Government approved implementation of Arogya Bengaluru Scheme
# - Arogya Bengaluru Scheme is under Brand Bengaluru campaign
# - Arogya Bengaluru Scheme will lead to up-gradation of 19 hospitals
# - Arogya Bengaluru Scheme will boost diagnostics facilities
# - Arogya Bengaluru Scheme will provide 60 plus tests free of cost
# - Arogya Bengaluru Scheme will provide dental services at 26 new points
# - BBMP Forest Wing’s Avenue Plantation initiative enhances Bengaluru's green cover
# - 1,13,000 saplings planted in Bengaluru
# - Five tree parks being developed under "Brand Bengaluru -Green Bengaluru" initiative
# - Lakes of Bengaluru have major historical value
# - Lakes of Bengaluru have major cultural value
# - Lakes of Bengaluru enhance livability of the city
# - Rs.35 crores allocated under “Brand Bengaluru -Green Bengaluru” grant
# - Bengaluru Climate Action Plan (BCAP) is associated with Climate Action Cell (CAC)
# - Bengaluru Climate Action Cell (CAC) commenced operations in February 2024
# - Bengaluru Climate Action Cell (CAC) marks a pivotal moment in city's commitment to addressing climate change
# - Bengaluru Climate Action Cell (CAC) has primary objective to facilitate implementation of Bengaluru Climate Action and Resilience Plan (BCAP)
# ...
# - Rs.50 crores (for Bengaluru Urban Tunnel Project) is expected to be utilized in the project
# - tenders have been invited for development of Padarayanapura road under Sugama Sanchara Bengaluru
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - BRUHAT BENGALURU MAHANAGARA PALIKE has a PERFORMANCE REPORT OF 2024-25
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Vibrant Bengaluru theme is under Brand Bengaluru Campaign
# - Vibrant Bengaluru theme is for the project Decorative Electrification Project
# - Chapter 2 is titled Bengaluru: Karnataka's prime urban centre
# - Bengaluru was known as ‘Garden City’
# - Bengaluru had abundance of greenery
# - Young minds made Bengaluru a software capital of the world
# - The metropolitan city (Bengaluru) registered highest growth rate of 44.6%
# - Bengaluru’s urban management has come under severe criticism
# - The report establishes a need for urgent structural changes in Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - Bengaluru Metropolitan Area (BMA) is projected to have a population of 20 million by 2040
# - Greater Bangalore Authority ensures Bengaluru remains as one city governance
# - Expert Committee's mandate focused on improving quality of life for all citizens in Bengaluru
# - State has overriding influence over Bengaluru
# - Bengaluru has a weak, one-year 'titular' mayor system
# - The garbage problem in Bengaluru has been festering for over three years
# - The garbage problem in Bengaluru is without a positive resolution
# - Existing infirmities are holding back Bengaluru
# - Bengaluru is prevented from realising its potential as the best city in India
# - Bengaluru is prevented from realising its potential as one of the truly liveable global cities in the world
# - The city (Bengaluru) needs to be an engine of economic growth
# - The city (Bengaluru) needs to be creating livelihoods
# - The city (Bengaluru) needs to be attracting investments
# - Realising the holistic vision for Bengaluru will call for political will
# - Realising the holistic vision for Bengaluru will call for administrative support
# - The Committee recommends a holistic structure for managing Bengaluru
# - A holistic structure for managing Bengaluru is guided by constitutional principles
# - Recommendations provide for the Greater Bengaluru Authority (GBA) as a Local Planning Authority (LPA)
# - The suggested architecture for managing Bengaluru promotes Political Devolution
# - The suggested architecture for managing Bengaluru promotes Decentralised Accountability
# - The suggested architecture for managing Bengaluru supports co-existence of larger Metropolitan governance structures
# - The suggested architecture for managing Bengaluru supports protecting the devolved powers at the lower levels
# - Metropolitan governance structures aim to protect and reinforce brand Bengaluru
# - The suggested architecture for managing Bengaluru includes ‘Watch dog’ mechanisms
# - A Greater Bengaluru Finance Commission is for fair and equitable distribution of resources
# - A Greater Bengaluru Finance Commission is for problem resolution
# - A Greater Bengaluru Services Ombudsman allows citizens to make their case for better civic services
# - A Municipalisation Committee is housed within the Greater Bengaluru Authority
# - The Committee suggested a 3 tier governance framework for Bengaluru
# - A 3 tier governance framework for Bengaluru includes Ward, Municipal Corporation, Greater Bengaluru Authority (GBA)
# - The current Bengaluru Metropolitan Area has a footprint of 1,307 sq kms
# - Bengaluru today has an inner core (within Outer Ring Road)
# - Bengaluru today has an outer periphery
# - Proposed Greater Bengaluru Finance Commission should set out a basis for financial devolution to the ward
# - Bengaluru's population is projected to be over 20 million by 2040
# - Wards in outer areas of Bengaluru have suffered in terms of infrastructure
# - Nearly half of Bengaluru's population lives in wards in the outer areas
# - Bengaluru has a population of 10 million
# - Bengaluru has an area of 709.5 sq kms
# - No city with Bengaluru's population and area operates as a single Corporation entity
# - Bengaluru's growth has been rapid since 2001
# - Bengaluru's growth is projected to continue until 2040
# - Bengaluru's growth has occurred beyond the Outer Ring Road
# - 5 Corporation solution balanced various areas of Bengaluru
# - 5 Corporation solution kept intact essential character of Bengaluru
# - 5 Corporation model epitomises a Bengaluru aligned to its historical roots
# - Kempegowda is Bengaluru’s founder
# - Kempegowda II moved base to Bengaluru
# - 4 pillars represent boundaries of Bengaluru
# - fear of loss of Bengaluru brand is an argument against splitting BBMP
# - brand Bengaluru is implicitly assumed to be dependent on BBMP remaining as a single unit
# - Brand Bengaluru is shaped by its people
# - Brand Bengaluru is shaped by its ethos
# - Brand Bengaluru is shaped by its culture
# - Brand Bengaluru is shaped by its vibrancy
# - Brand Bengaluru is shaped by its promise
# - BBMP cannot be considered sign post of brand Bengaluru
# - Founder of Bengaluru is unlikely to have visualised BBMP as the flag bearer of the city
# - Greater Bengaluru Authority is a recommendation for Bengaluru
# - Greater Bengaluru Authority will help build brand Bengaluru
# - Greater Bengaluru Authority will help sustain brand Bengaluru
# - Greater Bengaluru Authority will help nurture brand Bengaluru
# - directly elected Mayor will act as precursor to directly elected Metropolitan Mayor of the Greater Bengaluru Authority
# - Tier 2 and Tier 3 arrangements will work only if there is a Greater Bengaluru layer (Tier 1)
# - Greater Bengaluru layer (Tier 1) integrates all civic activities
# - Greater Bengaluru layer (Tier 1) takes responsibility for planning and administration of Bengaluru metropolitan activities
# - Lack of attention and future planning for the extended region is a cause of Bengaluru’s current woes
# - Haphazard development and lack of infrastructure provisioning in outlying areas has impacted the quality of life in Bengaluru adversely
# - Greater Bengaluru Authority (GBA) is the apex body
# - Greater Bengaluru Authority (GBA) is strongly advocated on multiple counts
# - Nearly all stakeholders consulted have voiced concerns about protecting the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about nurturing the Bengaluru brand
# - Nearly all stakeholders consulted have voiced concerns about growing the Bengaluru brand
# - Greater Bengaluru Authority (GBA) will ensure all activities in the metropolitan area are in sync with building brand Bengaluru
# - Lack of inter-agency coordination due to organisation silos is a complaint of Bengaluru citizens
# - Economic Development Agency has scope for Bengaluru to be at the forefront on city economy innovation
# - Footprint of the GBA is ideally Bengaluru Metropolitan Area (BMA)
# - Bengaluru Metropolitan Area (BMA) is also known as BDA area
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
# - proposed Greater Bengaluru Authority will be headed initially by Chief Minister
# - Greater Bengaluru Authority should go in for a directly elected ‘Metropolitan Mayor’
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - GBA includes 5 Bengaluru City MLAs
# - Bengaluru City MLAs are members of relevant Municipal Corporation
# - Greater Bengaluru Finance Commission is for fair and equitable distribution
# - Bengaluru needs a planning body
# - A planning body looks out for development activities on Bengaluru's outskirts
# - Several urban local bodies are almost contiguous to Bengaluru
# - Bengaluru is one city
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - BBMP (Estate Management) Rules 2024 provide for proper management of 6,818 properties
# - State Government grant was expected to be Rs.3,475.97 crores during FY 2024-25
# - BBMP collaborated with Karnataka State Tourism Development Corporation (KSTDC)
# - State government identified need for comprehensive solid waste management
# - Project for Integrated Solid Waste Management has been approved by state government
# - Proposal for land acquisition has been submitted to state government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 has been approved by the government
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 came into force from 01.01.2025
# - Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 enable BBMP to lease out or renew existing properties
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - implementation of Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024 is expected to generate more revenue
# - State Government has approved an action plan for "Sancharyukta Bengaluru" works
# - Karnataka State was a pioneer in initiating devolution of powers under Panchayat Raj
# - State has overriding influence over Bengaluru
# - Poor state of infrastructure and service delivery led citizens to distrust BBMP
# - No one seems responsible for the state of the city
# - Quarterly meetings give MLAs a handle on the state of civic affairs of their wards
# - The State has had a major role in the city
# - State level has no legal arrangement for managing a Metropolitan city
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - Economic development is not real-estate development
# - BBMP (Estate Management) Rules 2024 are expected to yield about Rs. 100 crores in lease revenues
# - Procurement of laboratory equipment cost 10000000
# - Repairs and renovations work targets development of 10 new playgrounds
# - 306 students achieved highest ranks in 10th Std, 2nd P.U. (12th) and final degree
# - BBMP took a landmark decision to keep parks open between 5 am till 10 pm
# - Waste collection and processing area is 50 to 100 acres
# - Rs. 100 crores will be spent on land acquisition (once approved)
# - Establishment of 22 dry waste collection units increased daily dry waste collection capacity by 100 tons
# - 100 women friendly toilets are being planned under 4 packages
# - More than 10,000 applications processed through Sakala
# - More than 10,000 applications processed through Sahaya
# - Establishment of three Hi-Tech Nurseries costs Rs.10 crores
# - Rs.10 crores is expected to be spent on RMP road widening in 2024-25
# - Rs.100 crores have been provided for K-RIDe (Karnataka Rail Infrastructure Development Company) under Brand Bengaluru - Sugama Sanchar Bengaluru
# - Black topping has a cost of Rs.100 crores
# - Rs.100 crores will be spent from earmarked Rs.300 crores
# - Rs.10 crores is expected to be spent in FY 2024-25 for flood mitigation and disaster management
# - Rs.100 crores has been allocated in FY 2024-25 for Vibrant Bengaluru theme
# - Bengaluru Metropolitan Area (BMA) has a present population of 10 million
# - 2007 amalgamation involved 110 villages
# - current BBMP area has a population of around 10 million
# - Elected category members (Ward Committee) number 10
# - 10% vote share for a candidate results in a seat in Ward Committee (Elected category)
# - Nominated category members (Ward Committee) number 10
# - Bengaluru has a population of 10 million
# - 5 Commissioners and 10 Zonal Commissioners would oversee administration in their designated areas
# - 5 Commissioners and 10 Zonal Commissioners would be more effective than current set up
# - MC 1 has Population decadal growth % 103
# - Current system of dumping municipal solid waste involves dumping waste from a city of 10 million
# - Villages outside BBMP have a population of 500-1000
# - growth corridors have area of 1710 sq kms
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Works for development of 14 New Parks are under progress
# - Grant of Rs.49 crores given for rejuvenation of 14 lakes
# - Grant of Rs.49 crores given for development of 14 lakes
# - Works in 14 lakes are under progress
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - 2014 Population is set out against each of the 5 Corporations
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Police stations 14
# - MC 5 has Road length (kms)/Sq. Kms 14.7
# - Provision of furniture to 40 schools cost 15099700
# - An additional 150 km of roads are being developed with white-topping from the year 2023-24
# - Rs. 15 crores were allocated under 15th Finance Commission Grants
# - Rs. 15 crores were allocated for development of 14 New Parks
# - Secondary scientific waste transfer centers have a capacity of 150 to 200 metric tons per day
# - Approximately 15,600 pourakarmikas are employed in health & sanitation wing of Bruhat Bengaluru Mahanagara Palike
# - 15,600 pourakarmikas are employed under direct payment system
# - Three Hi-Tech Nurseries being established under 15th Finance Commission grants
# - Grant of Rs.49 crores given under 15th Finance Commission grants
# - BBMP has provided sarees to 15,150 Pourakarmikas
# - BBMP has provided aprons to 15,150 Pourakarmikas
# - BBMP has provided sweaters to 15,150 Pourakarmikas
# - BBMP has provided track pants to 15,150 Pourakarmikas
# - Rs.150 crores are expected to be spent in 2024-25 (from re-appropriation)
# - Shri V. Ravichandar worked closely on urban issues for 15 years
# - Less than 50% of estimated 23 lakh properties paid property tax in 2014-15
# - Low property tax payment (2014-15) indicates a lax approach towards revenue mobilisation
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Population within Outer Ring Road (ORR) in BBMP (2015) was approximately equal to population outside Outer Ring Road (ORR) in BBMP (2015)
# - 2014-15 Property tax (Rs. crores including arrears) is set out against each of the 5 Corporations
# - MC 1 has Area (sq km) 150.5
# - MC 2 has Population decadal growth % 15
# - MC 3 has Area (sq km) 157.2
# - MC 5 has Population density (2011) 7,515 per sq.km
# - GBA includes 15 representatives from the Municipal Corporation level
# - 2007 amalgamation involved Bangalore Mahanagar Palike (BMP)
# - 2007 amalgamation involved 7 City Municipal Councils (CMC)
# - 2007 amalgamation involved 1 Town Municipal Council (TMC)
# - 2007 amalgamation involved 110 villages
# - 2007 amalgamation did not yield expected gains
# - Property tax rates have not been revised since 2007
# - The existing 198 wards were formed during the amalgamation of 2007
# - Single Corporation model (2007-2015) experienced unwieldy size
# - Single Corporation model (2007-2015) experienced poor governance and administration
# - Single Corporation model (2007-2015) experienced limited voice for citizens
# - Single Corporation model (2007-2015) experienced low revenue generation
# - Single Corporation model (2007-2015) experienced financial mismanagement
# - Earlier villages were outside the limits of the pre 2007 BMP
# - Bengaluru Urban District has area of 2190 sq kms
# - Bengaluru Urban District has considerable non-urban settlements
#
#
#
# --- End of Query ---

# %% [markdown]
# ## Refine and iterate
#
# ### Subtask:
# Refine the entity identification and triplet retrieval logic in the `augment_with_triplets` function based on the analysis of the test query results.

# %% [markdown]
# **Reasoning**:
# Review the current `augment_with_triplets` function and identify areas for improvement in entity recognition and triplet filtering based on the analysis of the test query results.

# %%
import re
import pandas as pd

def augment_with_triplets(query: str, results: dict, df_triplets: pd.DataFrame) -> list[str]:
    """
    Augments retrieved text chunks from Chroma DB with related triplets from a DataFrame.

    Args:
        query (str): The user query (not directly used for retrieval here, but for context).
        results (dict): The results from the Chroma DB query, containing 'documents'.
        df_triplets (pd.DataFrame): DataFrame containing knowledge graph triplets.

    Returns:
        list: A list of augmented text chunks.
    """
    augmented_chunks = []

    if 'documents' not in results or not results['documents']:
        print("Warning: No documents found in Chroma DB results.")
        return []

    retrieved_documents = results['documents'][0]

    # Pre-compile regex patterns for efficiency
    # Escape potential regex special characters in subject/object strings
    triplet_entities = set(df_triplets['subject'].astype(str).tolist() + df_triplets['object'].astype(str).tolist())
    entity_patterns = [(entity, re.compile(r'\b' + re.escape(entity) + r'\b', re.IGNORECASE)) for entity in triplet_entities]


    for doc in retrieved_documents:
        augmented_text = doc
        identified_entities = set()

        # Improved entity identification: Use pre-compiled regex patterns
        for entity, pattern in entity_patterns:
            if pattern.search(doc):
                identified_entities.add(entity)

        related_triplets_text = ""
        if identified_entities:
            related_triplets_text += "\n\nRelated Information from Knowledge Graph:\n"
            all_related_triplets = pd.DataFrame()

            for entity in identified_entities:
                # Find triplets where the entity is subject or object
                entity_triplets = df_triplets[(df_triplets['subject'].str.contains(entity, case=False, na=False)) |
                                              (df_triplets['object'].str.contains(entity, case=False, na=False))]
                all_related_triplets = pd.concat([all_related_triplets, entity_triplets]).drop_duplicates()

            # Triplet Filtering/Ranking (Simple approach: limit the number of triplets)
            # A more advanced approach could involve ranking based on entity frequency in the doc
            # or relevance to the query (though query-based ranking is complex here).
            max_triplets_per_doc = 10 # Limit the number of related triplets to avoid overwhelming the output
            if len(all_related_triplets) > max_triplets_per_doc:
                # Simple truncation; can be replaced with a more sophisticated ranking if needed
                all_related_triplets = all_related_triplets.head(max_triplets_per_doc)

            for index, row in all_related_triplets.iterrows():
                 related_triplets_text += f"- {row['subject']} {row['relation']} {row['object']}\n"


        augmented_text += related_triplets_text
        augmented_chunks.append(augmented_text)

    return augmented_chunks

# Test the refined function with a sample query
sample_query = "What is the role of Zonal Commissioners in BBMP?"
augmented_chunks_refined = augment_with_triplets(sample_query, results, df_triplets)

# Display the augmented chunks from the refined function
print("--- Augmented Chunks with Refined Logic ---")
for i, chunk in enumerate(augmented_chunks_refined):
    print(f"Augmented Chunk {i+1}:")
    print(chunk)
    print("\n")
# Out:
# --- Augmented Chunks with Refined Logic ---
# Augmented Chunk 1:
# Investment Opportunities
#
# Name of the Project
#
#
#
# Construction of 221 public toilets in Bengaluru City
#
# Construction of Skywalks in Bengaluru City
#
# Redevelopment of Existing Markets in Bengaluru City
#
# Redevelopment of Commercial Complex at Indiranagar,
# Bengaluru
#
# Redevelopment of Commercial Complex at Vijayanagar,
# Bengaluru
#
# Development of Animation, Visual Effects, Gaming and
#
# 29 comics (AVGC Lab)
#
# fo)
#
# Development of Digital Media City
#
# i]
#
# Development of LEGO Theme Park at Bengaluru.
#
# i)
#
# Development of Disney Land Theme Park at Bengaluru
#
# Development of Cruise Dinner Project at Halasuru Lake,
# Bengaluru
#
# IN)
# aN
#
# i]
# wo
#
# Development of Snow Park in Bengaluru
#
# Development of Arts & Crafts Village in Bengaluru
#
# i}
# ron)
#
# i}
# NI
#
# Development of Bengaluru Eye
#
# IK 2016 | BENGALURU URBAN
#
# Sector
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Industrial
# Infrastructure -IT
# Parks
#
# Industrial
# Infrastructure -IT
# Parks
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# Tourism
#
# NA
#
# 335
#
# 40
#
# 26
#
# 782
#
# 62
#
# 100
#
# 40
#
# 43
#
# NA
#
# NA
#
# 56
#
# 130
#
# NA
#
# Agency
#
# BBMP
#
# BBMP
#
# BBMP
#
# BDA
#
# BDA
#
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Karnataka
# Biotechnol
# ogy &
# Information
# Technolog
# y Services
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
# Tourism
# Departmen
# t
#
#
#
# Status
#
# Conceptualization
#
# Conceptualization
#
# Conceptualization
#
# Bidding Stage/
# DPR completed
#
# Conceptualization
#
# DPR under
# preparation
#
# DPR under
# preparation
#
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
# Conceptualization
#
# Conceptualization
#
# Related Information from Knowledge Graph:
# - Survey of 166 lakes is completed
# - actual boundaries need to be drawn after ward delimitation exercise is completed
# - 143 pending cases for renewal will be acted upon under Bruhat Bengaluru Mahanagara Palike (Estate Management) Rules 2024
# - 43 wards have a population of greater than 50,000
# - MC 3 has Population decadal growth % 43
# - Municipal Corporation functions derive from Article 243-W of the Twelfth Schedule of the Constitution
# - An Information Technology (IT) Cell has been operationalized by BBMP
# - Information Technology (IT) Cell is equipped with state of the art facilities
# - Information Technology (IT) Cell is equipped with robust systems and mechanism
# - A separate helpline has been opened for assisting information /clarifications / complaints regarding e-khatha process
#
#
#
# Augmented Chunk 2:
# Industry Profile
#
# - 315 Large Scale Industries with aggregated investment of INR 14793 Crore
#
# « 211Medium Scale Industries with aggregated investment of INR 1342 Crore
#
#
#
# + 74,282 small-scale industries with aggregated investment INR 41,213 Crore
#
# * World Economic Forum identified Bengaluru as the Innovation Cluster
# + Business Week placed Bengaluru among the 'Global Hot Spots of the 21* Century’
# + Bengaluru is also known as Silicon Valley and Technology Base in Asia
#
# + Bengaluru is one of the pioneers in the concept of industrial clusters with established industrial clusters
# like Whitefield, Electronics City, Peenya etc.
#
# + Peenya is the largest Industrial cluster in Asia
#
# - IT firms in Bengaluru employ about 35% of India’s pool of 1 million IT professionals and account for the
# highest IT-related exports in the country
#
# - Bengaluru is home to the biggest bio cluster in India with 137 Biotechnology companies, making it 40%
# of the total 340 such units in the country. Home to the biggest bio cluster in the Electronic City
#
# * Total 87 Fortune 500 MNCs, 2084 IT Companies and 195 BT companies are there in Bengaluru
#
# « Wellness Tourism: Bengaluru city facilitates over 6,000 patients from across the world with distinction
# of having largest number of systems of medicine approved by the WHO in asingle city
#
# + Bengaluru ranks the highest in India in the implementation and value of PPP projects
#
# *« Wheel & Axel Industry, with highest production unit in Asia
#
# Artisan Clusters:
#
# + Agarbatti, Rugs & Duries, Wood Carving, Shopping Bag/ Fancy Items, Toys and Decoration pieces, Brass
# and Copper Art Ware, Dolls from pulp, Jewellery,Metalware Grass, Leaf, Reed & Fibre, Earthier
# ware/pottery, Embroidery by hand, Printing of cloth by hand, Toys and Decoration pieces, Wood
# Furniture & Fixtures, Textile Handlooms
#
# MSME Clusters:
#
# Machine Tools, Power Loom , Electronic Goods , Readymade Garments , Light engineering, Leather
# Products
#
# Natural Resources:
# Felspar
#
# Source: DIC - Bengaluru Urban
#
# IK 2016 | BENGALURU URBAN Go
#
# Related Information from Knowledge Graph:
# - 6,819 properties have been identified
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
#
#
#
# Augmented Chunk 3:
# S N e D S h ot BENGALURU URBAN
#
# District Profile
#
# District Overview
# Connectivity
#
# Civic Infrastructure
# Tourism
#
# Power and Water
# Economic Profile
# Agricultural Profile
# Industry Profile
# Key Industries
#
# Annexure
#
# Related Information from Knowledge Graph:
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district
# - Bruhat Bengaluru Mahanagara Palike intended to build a 250 meter High Sky Deck
# - The 250 meter High Sky Deck aims to showcase Bengaluru city’s modernity
# - CIPC aims for more development of Bengaluru
# - Comprehensive solid waste management is part of Brand Bengaluru concept
#
#
#
# Augmented Chunk 4:
# Investment Opportunities
#
# Name of the Project
#
#
#
# Development of International Aerospace Museum at
# Jakkur in Bengaluru
#
# N
# foe}
#
# i]
# ©
#
# Bengaluru International Convention Centre
#
# sen)
# fe}
#
# Devanahalli Business Park, Bengaluru
#
# NT
#
# Development of Parking Management System in Bengaluru
#
# Construction of Eight Lane Peripheral Ring Road (PRR) To
# Bengaluru City
#
# en)
# N
#
# Redevelopment of Existing Market at Austin Town
#
# Redevelopment of BDA Shopping Complex at Domlur
#
# Redevelopment of BDA Complex at Indira Nagar
#
# Redevelopment of Existing Market at RT Nagar
#
# nT
#
# aN) aN) wW in)
# N n uo 4 ce =
#
# Redevelopment of Mavalli Market, RV. Road, Bengaluru
#
# rN)
# foo)
#
# Construction of Market Complex at Akkipete, Bengaluru
#
# Construction of 2000 Bus Shelters
#
# wW
# ©
#
# aS
# fe)
#
# Energy Efficient Street Lights
#
# IK 2016 | BENGALURU URBAN
#
# Sector
#
# Tourism
#
# Tourism
#
# Urban
# Infrastructure
#
# Transportation
#
# Transportation
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# Urban
# Infrastructure
#
# NA
#
# 1,035
#
# NA
#
# 55
#
# 11,950
#
# 123
#
# 21
#
# Boo
#
# 49
#
# NA
#
# NA
#
# NA
#
# NA
#
# 173
#
# NA
#
# 1,992
#
# 20
#
# 59
#
# 0.5
#
# NA
#
# NA
#
# NA
#
# Agency
#
# KSIIDC
#
# KSIIDC
#
# KSIIDC
#
# DULT
#
# BDA
#
# BDA
#
# BDA
#
# BDA
#
# BDA
#
# BBMP
#
# BBMP
#
# BBMP.
#
# BBMP.
#
#
#
# Status
#
# Conceptualization
#
# Bidding Stage/
# DPR completed
#
# DPR under
# preparation
#
# Bidding stage/
# DPR completed
#
# Bidding stage/
# DPR completed
#
# DPR under
# preparation
#
# Bidding stage/
# DPR completed
#
# Bidding stage/
# DPR completed
#
# Conceptualization
#
# DPR under
# preparation
#
# DPR under
# preparation
#
# Conceptualization
#
# Conceptualization
#
# Related Information from Knowledge Graph:
# - Survey of 166 lakes is completed
# - actual boundaries need to be drawn after ward delimitation exercise is completed
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - 225 wards formed in accordance with BBMP Act - 2020
# - New transfer policy came into effect from 04-07-2024
# - BBMP achieved highest property tax collection in the country in FY 2023-24
# - Property tax collection in FY 2023-24 was Rs.3,944 crores
# - Property tax collection for 2024-25 (till February 2025) was Rs.4,541.75 crores
# - Recovery of Rs. 1,277 crores arrears occurred between 22nd February 2024 and 30th November 2024
# - BBMP (Estate Management) Rules 2024 were promulgated by BBMP
#
#
#
# Augmented Chunk 5:
# Economic Profile
#
# 0 Highest contributor to the State economy with 33.3% contribution to
# GDDP (INR 99,325 Crore) (2012-2013)
#
# 6 Per capita annual income in the district is INR 2,02,340 for the year 2012-13
#
#
#
#
# 6 Country’s fourth largest fast moving consumer goods (FMCG) market
#
#
#
#
# Bengaluru Urban District’s Contribution to GSDP of Karnat:
#
# (2012-13)
# Description INR Contribution (%)
# Crore
# Total District GDP 99,325 33.3
# Agriculture and Allied 967 2.3
#
# (Agriculture, Animal
# Husbandry, Forestry, Fishing)
#
# Industry 30,028 36
# (Manufacturing,
# Construction, Mining)
#
# Services 68,330 39.5
# (Real estate, Hotels and
# restaurants, banking, and
# legal services)
#
#
#
#
#
# Bengaluru Urban GDP Trend (In INR Crore)
#
#
#
# 96,232 99,325
#
# 84,072 84,336 86,831
# | . |
#
# 2007-08 2008-09 2009-10 2010-11 2011-12 2012-13
#
#
#
# Source: State and District Domestic Product of Karnataka 14-15 m Primary MSecondary MTertiary © GDDP
#
# IK 2016 | BENGALURU URBAN gO
#
# Related Information from Knowledge Graph:
# - No one seems responsible for the state of the city
# - Quarterly meetings give MLAs a handle on the state of civic affairs of their wards
# - The State has had a major role in the city
# - new Bengaluru region Act will be needed to enable legal arrangement at the State level for managing a Metropolitan city
# - Bruhat Bengaluru Mahanagara Palike published Performance Report of 2024-25
# - Bruhat Bengaluru Mahanagara Palike Act - 2020 has been amended N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules are promulgated N/A
# - Bruhat Bengaluru Mahanagara Palike (Property tax Assessment, Recovery and Management) Rules has streamlined procedures
# - Pratham Education Foundation is in partnership with Bruhat Bengaluru Mahanagara Palike (BBMP)
# - The learning improvement program is across Bengaluru district

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The provided data included a DataFrame (`df_triplets`) containing knowledge graph triplets (subject, relation, object) and results (`results`) from a previous Chroma DB vector search (including retrieved documents, metadata, and distances).
# *   Initial analysis confirmed the structure and content of the triplet data, revealing various entities and relationships.
# *   The "Retrieve then Augment" strategy was selected as the most suitable approach for integrating vector search results with the knowledge graph, as it directly utilizes the retrieved text chunks and enriches them with KG information.
# *   An `augment_with_triplets` function was implemented to perform this augmentation. It identifies potential entities in retrieved text chunks by matching subjects and objects from the triplets and then retrieves related triplets from the `df_triplets` DataFrame.
# *   Testing with sample queries demonstrated that the system could retrieve relevant text and augment it with related triplet information.
# *   Refinements were made to the `augment_with_triplets` function to improve entity identification using pre-compiled regex patterns and to limit the number of augmented triplets to enhance relevance and readability.
#
# ### Insights or Next Steps
#
# *   Implement a more sophisticated entity recognition method (e.g., Named Entity Recognition) instead of simple string matching to improve the accuracy of identifying entities in the retrieved text.
# *   Develop a more nuanced ranking or filtering mechanism for the retrieved triplets to ensure the most relevant triplets are used for augmentation, potentially considering the context of the query or the prominence of the entities in the text.
